# %% [markdown]
# # GSE243639 - Martirosyan - pySCENIC pipeline (Embedded version)
#
# **Author:** Vincent Gardeux
#
# **Date Created:** 05/03/2024
#
# **Date Modified:** 05/03/2024

# %% [markdown]
# # Libraries

# %%
# !pip install anndata regdiffusion polars numpy==1.23.5
# I need polars to load the csv fast enough. Installing within the Docker...
# Out:
# Requirement already satisfied: anndata in /opt/venv/lib/python3.10/site-packages (0.11.4)
# Requirement already satisfied: regdiffusion in /opt/venv/lib/python3.10/site-packages (0.1.0)
# Collecting polars
#   Downloading polars-1.29.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.8/34.8 MB 61.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy==1.23.5 in /opt/venv/lib/python3.10/site-packages (1.23.5)
# Requirement already satisfied: pandas!=2.1.0rc0,!=2.1.2,>=1.4 in /opt/venv/lib/python3.10/site-packages (from anndata) (1.5.1)
# Requirement already satisfied: array-api-compat!=1.5,>1.4 in /opt/venv/lib/python3.10/site-packages (from anndata) (1.11.2)
# Requirement already satisfied: packaging>=24.2 in /opt/venv/lib/python3.10/site-packages (from anndata) (25.0)
# Requirement already satisfied: exceptiongroup in /opt/venv/lib/python3.10/site-packages (from anndata) (1.2.0)
# Requirement already satisfied: natsort in /opt/venv/lib/python3.10/site-packages (from anndata) (8.4.0)
# Requirement already satisfied: scipy>1.8 in /opt/venv/lib/python3.10/site-packages (from anndata) (1.9.3)
# Requirement already satisfied: h5py>=3.7 in /opt/venv/lib/python3.10/site-packages (from anndata) (3.7.0)
# Requirement already satisfied: tqdm in /opt/venv/lib/python3.10/site-packages (from regdiffusion) (4.64.1)
# Requirement already satisfied: scikit-learn in /opt/venv/lib/python3.10/site-packages (from regdiffusion) (1.1.3)
# Requirement already satisfied: pyvis in /opt/venv/lib/python3.10/site-packages (from regdiffusion) (0.3.2)
# Requirement already satisfied: torch in /opt/venv/lib/python3.10/site-packages (from regdiffusion) (2.7.0)
# Requirement already satisfied: scanpy in /opt/venv/lib/python3.10/site-packages (from regdiffusion) (1.10.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/venv/lib/python3.10/site-packages (from pandas!=2.1.0rc0,!=2.1.2,>=1.4->anndata) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/venv/lib/python3.10/site-packages (from pandas!=2.1.0rc0,!=2.1.2,>=1.4->anndata) (2022.6)
# Requirement already satisfied: jsonpickle>=1.4.1 in /opt/venv/lib/python3.10/site-packages (from pyvis->regdiffusion) (4.0.5)
# Requirement already satisfied: jinja2>=2.9.6 in /opt/venv/lib/python3.10/site-packages (from pyvis->regdiffusion) (3.1.2)
# Requirement already satisfied: ipython>=5.3.0 in /opt/venv/lib/python3.10/site-packages (from pyvis->regdiffusion) (8.22.2)
# Requirement already satisfied: networkx>=1.11 in /opt/venv/lib/python3.10/site-packages (from pyvis->regdiffusion) (2.8.8)
# Requirement already satisfied: numba>=0.56 in /opt/venv/lib/python3.10/site-packages (from scanpy->regdiffusion) (0.56.4)
# Requirement already satisfied: statsmodels>=0.13 in /opt/venv/lib/python3.10/site-packages (from scanpy->regdiffusion) (0.14.4)
# Requirement already satisfied: session-info in /opt/venv/lib/python3.10/site-packages (from scanpy->regdiffusion) (1.0.1)
# Requirement already satisfied: pynndescent>=0.5 in /opt/venv/lib/python3.10/site-packages (from scanpy->regdiffusion) (0.5.8)
# Requirement already satisfied: legacy-api-wrap>=1.4 in /opt/venv/lib/python3.10/site-packages (from scanpy->regdiffusion) (1.4.1)
# Requirement already satisfied: patsy!=1.0.0 in /opt/venv/lib/python3.10/site-packages (from scanpy->regdiffusion) (1.0.1)
# Requirement already satisfied: seaborn>=0.13 in /opt/venv/lib/python3.10/site-packages (from scanpy->regdiffusion) (0.13.2)
# Requirement already satisfied: matplotlib>=3.6 in /opt/venv/lib/python3.10/site-packages (from scanpy->regdiffusion) (3.10.3)
# Requirement already satisfied: joblib in /opt/venv/lib/python3.10/site-packages (from scanpy->regdiffusion) (1.2.0)
# Requirement already satisfied: umap-learn!=0.5.0,>=0.5 in /opt/venv/lib/python3.10/site-packages (from scanpy->regdiffusion) (0.5.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/venv/lib/python3.10/site-packages (from scikit-learn->regdiffusion) (3.1.0)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /opt/venv/lib/python3.10/site-packages (from torch->regdiffusion) (11.7.1.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /opt/venv/lib/python3.10/site-packages (from torch->regdiffusion) (2.26.2)
# Requirement already satisfied: triton==3.3.0 in /opt/venv/lib/python3.10/site-packages (from torch->regdiffusion) (3.3.0)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /opt/venv/lib/python3.10/site-packages (from torch->regdiffusion) (11.3.0.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /opt/venv/lib/python3.10/site-packages (from torch->regdiffusion) (12.6.77)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/venv/lib/python3.10/site-packages (from torch->regdiffusion) (4.13.2)
# Requirement already satisfied: filelock in /opt/venv/lib/python3.10/site-packages (from torch->regdiffusion) (3.18.0)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /opt/venv/lib/python3.10/site-packages (from torch->regdiffusion) (0.6.3)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /opt/venv/lib/python3.10/site-packages (from torch->regdiffusion) (12.6.4.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /opt/venv/lib/python3.10/site-packages (from torch->regdiffusion) (12.6.77)
# Requirement already satisfied: sympy>=1.13.3 in /opt/venv/lib/python3.10/site-packages (from torch->regdiffusion) (1.14.0)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /opt/venv/lib/python3.10/site-packages (from torch->regdiffusion) (12.5.4.2)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /opt/venv/lib/python3.10/site-packages (from torch->regdiffusion) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /opt/venv/lib/python3.10/site-packages (from torch->regdiffusion) (12.6.85)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /opt/venv/lib/python3.10/site-packages (from torch->regdiffusion) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /opt/venv/lib/python3.10/site-packages (from torch->regdiffusion) (9.5.1.17)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /opt/venv/lib/python3.10/site-packages (from torch->regdiffusion) (10.3.7.77)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /opt/venv/lib/python3.10/site-packages (from torch->regdiffusion) (1.11.1.6)
# Requirement already satisfied: fsspec in /opt/venv/lib/python3.10/site-packages (from torch->regdiffusion) (2022.11.0)
# Requirement already satisfied: setuptools>=40.8.0 in /opt/venv/lib/python3.10/site-packages (from triton==3.3.0->torch->regdiffusion) (63.2.0)
# Requirement already satisfied: pygments>=2.4.0 in /opt/venv/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis->regdiffusion) (2.17.2)
# Requirement already satisfied: decorator in /opt/venv/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis->regdiffusion) (5.1.1)
# Requirement already satisfied: stack-data in /opt/venv/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis->regdiffusion) (0.6.3)
# Requirement already satisfied: jedi>=0.16 in /opt/venv/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis->regdiffusion) (0.19.1)
# Requirement already satisfied: traitlets>=5.13.0 in /opt/venv/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis->regdiffusion) (5.14.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/venv/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis->regdiffusion) (3.0.43)
# Requirement already satisfied: matplotlib-inline in /opt/venv/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis->regdiffusion) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /opt/venv/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis->regdiffusion) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/venv/lib/python3.10/site-packages (from jinja2>=2.9.6->pyvis->regdiffusion) (2.1.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/venv/lib/python3.10/site-packages (from matplotlib>=3.6->scanpy->regdiffusion) (1.4.8)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/venv/lib/python3.10/site-packages (from matplotlib>=3.6->scanpy->regdiffusion) (1.3.2)
# Requirement already satisfied: pillow>=8 in /opt/venv/lib/python3.10/site-packages (from matplotlib>=3.6->scanpy->regdiffusion) (9.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/venv/lib/python3.10/site-packages (from matplotlib>=3.6->scanpy->regdiffusion) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /opt/venv/lib/python3.10/site-packages (from matplotlib>=3.6->scanpy->regdiffusion) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/venv/lib/python3.10/site-packages (from matplotlib>=3.6->scanpy->regdiffusion) (4.58.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /opt/venv/lib/python3.10/site-packages (from numba>=0.56->scanpy->regdiffusion) (0.39.1)
# Requirement already satisfied: six>=1.5 in /opt/venv/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas!=2.1.0rc0,!=2.1.2,>=1.4->anndata) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/venv/lib/python3.10/site-packages (from sympy>=1.13.3->torch->regdiffusion) (1.3.0)
# Requirement already satisfied: stdlib_list in /opt/venv/lib/python3.10/site-packages (from session-info->scanpy->regdiffusion) (0.11.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/venv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis->regdiffusion) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/venv/lib/python3.10/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis->regdiffusion) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/venv/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis->regdiffusion) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /opt/venv/lib/python3.10/site-packages (from stack-data->ipython>=5.3.0->pyvis->regdiffusion) (2.0.1)
# Requirement already satisfied: pure-eval in /opt/venv/lib/python3.10/site-packages (from stack-data->ipython>=5.3.0->pyvis->regdiffusion) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/venv/lib/python3.10/site-packages (from stack-data->ipython>=5.3.0->pyvis->regdiffusion) (2.4.1)
# Installing collected packages: polars
# Successfully installed polars-1.29.0
#
# [notice] A new release of pip available: 22.2.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
# Fix OPENBLAS Warnings
import os
param_n_workers = 64 # We have 112 CPUs/cores, each process will automatically be associated to a different CPU by the OS scheduler
param_threads_per_worker=2 # We have 2 threads per CPU on SVEN (hyper-threading). See lscpu command. Note: Here they are not used apparently. Setting to 1 or 2 gives similar c. time
os.environ['OPENBLAS_NUM_THREADS'] = f"{param_n_workers * param_threads_per_worker}"
os.environ['MKL_NUM_THREADS'] = f"{param_n_workers * param_threads_per_worker}"
os.environ['OMP_NUM_THREADS'] = f"{param_n_workers * param_threads_per_worker}"
os.environ['NUMEXPR_MAX_THREADS'] = f"{param_n_workers * param_threads_per_worker}"

# import dependencies
import pandas as pd
import numpy as np
import regdiffusion as rd # For replacing grnboost2 which is slow as hell and bugs (stalls) when there are more than ~1.5B elements in the matrix
import polars as pl
import pickle
import pytz

from datetime import datetime
from arboreto.utils import load_tf_names
from arboreto.algo import grnboost2
from distributed import Client, LocalCluster

from ctxcore.rnkdb import FeatherRankingDatabase as RankingDatabase
from pyscenic.binarization import binarize
from pyscenic.utils import modules_from_adjacencies
from pyscenic.prune import prune2df, df2regulons
from pyscenic.aucell import aucell

# %% [markdown]
# # Parameters

# %%
# [Input] Count matrix file to use
EXPRESSION_MTX_FNAME = '/data/gardeux/Neuro_Droso_ND75KD/data/Martirosyan_2024/GSE243639_Filtered_count_table.csv.gz' # From https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE243639

# Open CSV count matrix
f_m = pl.read_csv(EXPRESSION_MTX_FNAME)
f_gene_names = f_m[:, 0].to_list()  # First column as list of strings
f_cell_names = f_m.columns[1:]      # Column names (excluding first column)

# Create expression matrix
ex_matrix = pd.DataFrame(f_m[:, 1:], columns = f_cell_names, index = f_gene_names) # 33537 genes x 83484 cells

# [Input] Transcription factors list (SCENIC step 1: GRNBoost2)
f_tfs = "/data/gardeux/Neuro_Droso_ND75KD/data/allTFs_hg38.txt" # From https://resources.aertslab.org/cistarget/tf_lists/
# Derive list of Transcription Factors(TF)
tf_names = load_tf_names(f_tfs)

# [Output] Adjacency matrix (SCENIC step 1: GRNBoost2)
adj_matrix = "/data/gardeux/Neuro_Droso_ND75KD/data/Martirosyan_2024/Martirosyan_adj.csv"

# [Input] Ranking databases (SCENIC step 2-3: cisTarget)
f_db_names = ["/data/gardeux/Neuro_Droso_ND75KD/data/hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings.feather"] # From pySCENIC db: https://resources.aertslab.org/cistarget/databases/homo_sapiens/hg38/refseq_r80/mc_v10_clust/gene_based/
# Alternatively: f_db_names = ["/data/gardeux/Neuro_Droso_ND75KD/data/hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings.feather"]
dbs = [RankingDatabase(fname=f_name, name=os.path.basename(f_name)) for f_name in f_db_names]

# [Input] Motif databases (SCENIC step 2-3: cisTarget)
f_motif_path = "/data/gardeux/Neuro_Droso_ND75KD/data/motifs-v10nr_clust-nr.hgnc-m0.001-o0.0.tbl" # From pySCENIC db: https://resources.aertslab.org/cistarget/motif2tf/

# [Output] Regulons (SCENIC step 2-3: cisTarget)
f_motifs_path = "/data/gardeux/Neuro_Droso_ND75KD/data/Martirosyan_2024/Martirosyan_motifs.tsv"
f_modules_path = "/data/gardeux/Neuro_Droso_ND75KD/data/Martirosyan_2024/Martirosyan_modules.tsv"
f_regulons_path = "/data/gardeux/Neuro_Droso_ND75KD/data/Martirosyan_2024/Martirosyan_regulons.tsv"
f_regulons_aucell_path = "/data/gardeux/Neuro_Droso_ND75KD/data/Martirosyan_2024/Martirosyan_regulons_aucell.tsv"
f_regulons_binarized_aucell_path = "/data/gardeux/Neuro_Droso_ND75KD/data/Martirosyan_2024/Martirosyan_regulons_aucell_binarized.tsv"
f_regulons_binarization_thresholds_aucell_path = "/data/gardeux/Neuro_Droso_ND75KD/data/Martirosyan_2024/Martirosyan_regulons_aucell_binarization_thresholds.tsv"

# Restrict matrix to feather genes
ranking_feather = pd.read_feather(f_db_names[0])
overlap_values = ex_matrix.index[pd.Series(ex_matrix.index).isin(ranking_feather.columns)].unique()
ex_matrix = ex_matrix.loc[overlap_values, :]

ex_matrix # 20653 genes × 83484 cells
# Out:
#          s.0096_AAACCCAAGTACGAGC.1  s.0096_AAACCCACACAGCGCT.1  \
# FAM138A                          0                          0
# OR4F5                            0                          0
# OR4F29                           0                          0
# OR4F16                           0                          0
# FAM87B                           0                          0
# ...                            ...                        ...
# DIP2A                            0                          1
# S100B                            2                          0
# PRMT2                            0                          0
# MAFIP                            0                          0
# FAM231C                          0                          0
#
#          s.0096_AAACCCACAGATAAAC.1  s.0096_AAACCCAGTCCGGATC.1  \
# FAM138A                          0                          0
# OR4F5                            0                          0
# OR4F29                           0                          0
# OR4F16                           0                          0
# FAM87B                           0                          0
# ...                            ...                        ...
# DIP2A                            1                          4
# S100B                            1                          1
# PRMT2                            1                          0
# MAFIP                            0                          0
# FAM231C                          0                          0
#
#          s.0096_AAACCCAGTCTCTCAC.1  s.0096_AAACCCAGTGAATTGA.1  \
# FAM138A                          0                          0
# OR4F5                            0                          0
# OR4F29                           0                          0
# OR4F16                           0                          0
# FAM87B                           0                          0
# ...                            ...                        ...
# DIP2A                            1                          2
# S100B                            0                          2
# PRMT2                            1                          2
# MAFIP                            0                          0
# FAM231C                          0                          0
#
#          s.0096_AAACCCAGTTTACGAC.1  s.0096_AAACCCATCATGGAGG.1  \
# FAM138A                          0                          0
# OR4F5                            0                          0
# OR4F29                           0                          0
# OR4F16                           0                          0
# FAM87B                           0                          0
# ...                            ...                        ...
# DIP2A                            1                          0
# S100B                            0                          0
# PRMT2                            0                          0
# MAFIP                            0                          0
# FAM231C                          0                          0
#
#          s.0096_AAACCCATCCGTGCGA.1  s.0096_AAACCCATCGCGAAGA.1  ...  \
# FAM138A                          0                          0  ...
# OR4F5                            0                          0  ...
# OR4F29                           0                          0  ...
# OR4F16                           0                          0  ...
# FAM87B                           0                          0  ...
# ...                            ...                        ...  ...
# DIP2A                            1                          0  ...
# S100B                            8                          0  ...
# PRMT2                            4                          1  ...
# MAFIP                            0                          0  ...
# FAM231C                          0                          0  ...
#
#          s.0165_TTTGATCCAGAGGTTG.1  s.0165_TTTGGTTAGCGCCTTG.1  \
# FAM138A                          0                          0
# OR4F5                            0                          0
# OR4F29                           0                          0
# OR4F16                           0                          0
# FAM87B                           0                          0
# ...                            ...                        ...
# DIP2A                            0                          0
# S100B                            0                          0
# PRMT2                            0                          0
# MAFIP                            0                          0
# FAM231C                          0                          0
#
#          s.0165_TTTGGTTCAAACTAAG.1  s.0165_TTTGGTTCATGCCGGT.1  \
# FAM138A                          0                          0
# OR4F5                            0                          0
# OR4F29                           0                          0
# OR4F16                           0                          0
# FAM87B                           0                          0
# ...                            ...                        ...
# DIP2A                            1                          1
# S100B                            5                          0
# PRMT2                            1                          0
# MAFIP                            0                          0
# FAM231C                          0                          0
#
#          s.0165_TTTGGTTGTAGAGATT.1  s.0165_TTTGGTTTCCGCCTAT.1  \
# FAM138A                          0                          0
# OR4F5                            0                          0
# OR4F29                           0                          0
# OR4F16                           0                          0
# FAM87B                           0                          0
# ...                            ...                        ...
# DIP2A                            1                          1
# S100B                            0                          6
# PRMT2                            0                          1
# MAFIP                            0                          0
# FAM231C                          0                          0
#
#          s.0165_TTTGGTTTCTCGTTTA.1  s.0165_TTTGTTGCAAGTTCGT.1  \
# FAM138A                          0                          0
# OR4F5                            0                          0
# OR4F29                           0                          0
# OR4F16                           0                          0
# FAM87B                           0                          0
# ...                            ...                        ...
# DIP2A                            1                          0
# S100B                            0                          0
# PRMT2                            0                          0
# MAFIP                            0                          0
# FAM231C                          0                          0
#
#          s.0165_TTTGTTGCATGTTCAG.1  s.0165_TTTGTTGCATTACTCT.1
# FAM138A                          0                          0
# OR4F5                            0                          0
# OR4F29                           0                          0
# OR4F16                           0                          0
# FAM87B                           0                          0
# ...                            ...                        ...
# DIP2A                            1                          0
# S100B                            2                          0
# PRMT2                            0                          0
# MAFIP                            0                          0
# FAM231C                          0                          0
#
# [20653 rows x 83484 columns]

# %% [markdown]
# # SCENIC steps
#
# ## STEP 1: Gene regulatory network inference, and generation of co-expression modules
#
# ### 1.a. GRN inference using the GRNBoost2 algorithm
#
# In the initial phase of the pySCENIC pipeline the single cell expression profiles are used to infer co-expression modules from.
#
# Run GRNboost from arboreto to infer co-expression modules
#
# The arboreto package is used for this phase of the pipeline.
#
# *Output:* List of adjacencies between a TF and its targets.

# %% [markdown]
# Run GRNBoost2 algorithm

# %%
start = datetime.now(pytz.timezone('Europe/Paris'))
print("Start time:", start.strftime("%H:%M:%S"))

# Prepare the multithreading
cluster = LocalCluster(name='grn_call', dashboard_address=":12345", n_workers=param_n_workers, threads_per_worker=param_threads_per_worker)
client = Client(cluster)

# Here I run the function within the package (no CLI)
adjacencies = grnboost2(expression_data=ex_matrix.transpose(), tf_names=tf_names, seed=42, verbose=True, client_or_address=client)
            
# Shutting down cluster
client.close()
cluster.close()
    
end = datetime.now(pytz.timezone('Europe/Paris'))
print("End time:", end.strftime("%H:%M:%S"))
print("Running time:", (end - start))

# Note: Takes ~18hrs52mn with n_workers=12, threads_per_worker=8
# Out:
# Start time: 13:20:48
# preparing dask client
# parsing input
# creating dask graph
# 12 partitions
# computing dask graph
# not shutting down client, client was created externally
# finished
# End time: 08:12:56
# Running time: 18:52:07.946933

# %%
adjacencies.to_csv(adj_matrix, index=False, sep=',')
#adjacencies = pd.read_csv(adj_matrix, sep=',', na_filter=False) # If na_filter=True, the nan gene is detected as NaN
adjacencies

# %%
print(adjacencies.TF.nunique(), "unique TF-modules were found ( out of",len(tf_names),").")
# Out:
# 1774 unique TF-modules were found ( out of 1892 ).

# %%
print(adjacencies.target.nunique(), "unique targets were found ( out of",len(ex_matrix.index),").")
# Out:
# 19384 unique targets were found ( out of 19384 ).

# %%
adjacencies.TF.isin(tf_names).all()
# Out:
# True

# %% [markdown]
# ## STEP 2-3: Regulon prediction aka cisTarget
#
# *Output:* List of adjacencies between a TF and its targets.
#
# ### 2.a. Running regulon prediction using cisTarget
#
# Here, we use the --mask_dropouts option, which affects how the correlation between TF and target genes is calculated during module creation. It is important to note that prior to pySCENIC v0.9.18, the default behavior was to mask dropouts, while in v0.9.18 and later, the correlation is performed using the entire set of cells (including those with zero expression). When using the modules_from_adjacencies function directly in python instead of via the command line, the rho_mask_dropouts option can be used to control this.

# %% [markdown]
# **Note:** I kept same parameters than when I ran pySCENIC on our own dataset. It produces 1618 regulons when using TF list from Aerts.

# %%
modules = list(modules_from_adjacencies(adjacencies, ex_matrix.transpose(), rho_mask_dropouts=True, keep_only_activating=True)) # rho_mask_dropouts=True
# Out:
# 2025-05-14 08:23:03,729 - pyscenic.utils - INFO - Calculating Pearson correlations.
#
# 2025-05-14 08:23:06,172 - pyscenic.utils - WARNING - Note on correlation calculation: the default behaviour for calculating the correlations has changed after pySCENIC verion 0.9.16. Previously, the default was to calculate the correlation between a TF and target gene using only cells with non-zero expression values (mask_dropouts=True). The current default is now to use all cells to match the behavior of the R verision of SCENIC. The original settings can be retained by setting 'rho_mask_dropouts=True' in the modules_from_adjacencies function, or '--mask_dropouts' from the CLI.
# 	Dropout masking is currently set to [True].
#
# 2025-05-14 09:05:39,766 - pyscenic.utils - INFO - Creating modules.

# %%
modules_df = pd.DataFrame(index = range(0, len(modules)), columns = ("Regulon", "TF", "TFTargetGenesCorrelation", "NbMarkers", "Context", "NES", "Markers"))
for j in range(0, len(modules)):
    # Setting values
    context = list(modules[j].context)
    modules_df["Regulon"].iloc[j] = modules[j].name
    modules_df["TF"].iloc[j] = modules[j].transcription_factor
    modules_df["TFTargetGenesCorrelation"].iloc[j] = context[0]
    modules_df["NbMarkers"].iloc[j] = len(set(modules[j].gene2weight))
    modules_df["Context"].iloc[j] = context[1]
    modules_df["NES"].iloc[j] = modules[j].score
    modules_df["Markers"].iloc[j] = ','.join(list(modules[j].gene2weight))

modules_df = modules_df.sort_values(by='NbMarkers', ascending=False)
modules_df.to_csv(f_modules_path, index=False, sep = "\t")
modules_df
# Out:
#                 Regulon      TF TFTargetGenesCorrelation NbMarkers  \
# 280   Regulon for GTF2I   GTF2I             weight>75.0%      7113
# 517     Regulon for NF1     NF1             weight>75.0%      6972
# 715   Regulon for RUFY3   RUFY3             weight>75.0%      6916
# 736    Regulon for SFPQ    SFPQ             weight>75.0%      6890
# 441   Regulon for MAPK1   MAPK1             weight>75.0%      6764
# ...                 ...     ...                      ...       ...
# 15     Regulon for ALX4    ALX4             weight>75.0%        20
# 5472             ZBTB33  ZBTB33           top10perTarget        20
# 5048               MAFK    MAFK           top10perTarget        20
# 4372             PRDM10  PRDM10            top5perTarget        20
# 5975               E2F8    E2F8           top50perTarget        20
#
#          Context  NES                                            Markers
# 280   activating  0.0  CLASP2,ARHGAP21,TCF12,DLG2,MAP4K5,ARAP2,NCAM1,...
# 517   activating  0.0  FTX,CHD9,ARID1B,WDFY3,TCF12,ZSWIM6,N4BP2L2,TCF...
# 715   activating  0.0  DST,MAPK10,SASH1,ANK2,FUT9,CDH20,KIF1B,ADGRB3,...
# 736   activating  0.0  AKT3,BIRC6,HNRNPA2B1,TNKS,JMJD1C,ARID1B,MED13L...
# 441   activating  0.0  GNAQ,MYCBP2,DDX5,VPS13B,CAMK2D,CSNK1A1,BIRC6,T...
# ...          ...  ...                                                ...
# 15    activating  0.0  CYP1B1,CNN2,NID2,FOXD1,CES1,LINC00924,A4GALT,P...
# 5472  activating  0.0  CARTPT,CELA1,CENPM,FIZ1,KBTBD4,KRT7,PLEKHG4B,R...
# 5048  activating  0.0  ADAMTS9-AS1,ARNTL2-AS1,CCM2L,CD248,EFNA3,JAG2,...
# 4372  activating  0.0  BTNL8,C20orf202,CHIA,CYLC1,GLRA4,KCTD14,LINC01...
# 5975  activating  0.0  ASF1B,ASPM,BUB1B,CDT1,CENPU,DTL,ESCO2,FAM111B,...
#
# [7251 rows x 7 columns]

# %%
print(modules_df.TF.nunique(), "unique TF-modules were found ( out of",len(tf_names),"). Modules with less than 20 markers were filtered out.")
# Out:
# 1618 unique TF-modules were found ( out of 1892 ). Modules with less than 20 markers were filtered out.

# %%
start = datetime.now(pytz.timezone('Europe/Paris'))
print("Start time:", start.strftime("%H:%M:%S"))

df = prune2df(dbs, modules, f_motif_path, num_workers=param_n_workers, weighted_recovery=False, rank_threshold = 1500, nes_threshold=3, motif_similarity_fdr=0.001, auc_threshold=0.05, filter_for_annotation=False)
    
end = datetime.now(pytz.timezone('Europe/Paris'))
print("End time:", end.strftime("%H:%M:%S"))
print("Running time:", (end - start))
# Note: 36mn27 with num_workers=12

df.to_csv(f_motifs_path,sep = "\t")
#df
# Out:
# Start time: 10:50:28
# End time: 11:26:01
# Running time: 0:35:32.368071

# %%
print(len(set(df.index.get_level_values('TF').values)), "regulons were kept, after pruning")
# Out:
# 1618 regulons were kept, after pruning

# %%
# Look for main regulons
print("ATF4", "ATF4" in df.index.get_level_values('TF').values, sep="\t")
# Out:
# ATF4	True

# %%
print("Size of Dataframe:", len(df))
drop_indexes = []
for j in range(0, len(df)):
    # Setting values
    if(len(df["Enrichment"]["TargetGenes"][j]) == 0): drop_indexes.append(df.index[j])
df_filtered = df["Enrichment"].drop(index=drop_indexes)
print("Size of Dataframe:", len(df_filtered))
# Out:
# Size of Dataframe: 285023
# Size of Dataframe: 285023

# %% [markdown]
# These "modules" are then combined into regulons, by taking the top NES for each TF (for main Motif, and final score of regulon). All genes are bundled together.

# %%
# This dataframe can then be converted to regulons.
regulons = df2regulons(df_filtered)
# Out:
# Create regulons from a dataframe of enriched features.
# Additional columns saved: []

# %%
regulon_df = pd.DataFrame(index = range(0, len(regulons)), columns = ("Regulon", "TF", "TFTargetGenesCorrelation", "NbMarkers", "Motif", "NES", "Markers"))
for j in range(0, len(regulons)):
    # Fixing order of set
    context = list(regulons[j].context)
    if(context[0].endswith(".png")):
        tmp = context[0]
        context[0] = context[1]
        context[1] = tmp
    # Setting values
    regulon_df["Regulon"].iloc[j] = regulons[j].name
    regulon_df["TF"].iloc[j] = regulons[j].transcription_factor
    regulon_df["TFTargetGenesCorrelation"].iloc[j] = context[0]
    regulon_df["NbMarkers"].iloc[j] = len(set(regulons[j].gene2weight))
    regulon_df["Motif"].iloc[j] = "https://resources.aertslab.org/cistarget/motif_collections/v10nr_clust_public/logos/" + context[1]
    regulon_df["NES"].iloc[j] = regulons[j].score
    regulon_df["Markers"].iloc[j] = ','.join(list(regulons[j].gene2weight))

regulon_df = regulon_df.sort_values(by='NbMarkers', ascending=False)
regulon_df.to_csv(f_regulons_path, index=False, sep = "\t")
regulon_df
# Out:
#          Regulon       TF TFTargetGenesCorrelation NbMarkers  \
# 333     GTF2I(+)    GTF2I               activating      6313
# 982     TCF12(+)    TCF12               activating      5307
# 523     MBNL2(+)    MBNL2               activating      5305
# 602       NF1(+)      NF1               activating      5019
# 838     RUFY3(+)    RUFY3               activating      4999
# ...          ...      ...                      ...       ...
# 445      IRX4(+)     IRX4               activating        34
# 748   POU5F1B(+)  POU5F1B               activating        34
# 280     FOXN4(+)    FOXN4               activating        24
# 427      IL21(+)     IL21               activating        20
# 1003   TFAP2D(+)   TFAP2D               activating        18
#
#                                                   Motif       NES  \
# 333   https://resources.aertslab.org/cistarget/motif...  5.911895
# 982   https://resources.aertslab.org/cistarget/motif...  4.792579
# 523   https://resources.aertslab.org/cistarget/motif...  5.155327
# 602   https://resources.aertslab.org/cistarget/motif...  9.724204
# 838   https://resources.aertslab.org/cistarget/motif...  6.258469
# ...                                                 ...       ...
# 445   https://resources.aertslab.org/cistarget/motif...  4.299165
# 748   https://resources.aertslab.org/cistarget/motif...  5.366329
# 280   https://resources.aertslab.org/cistarget/motif...  4.978754
# 427   https://resources.aertslab.org/cistarget/motif...  5.355578
# 1003  https://resources.aertslab.org/cistarget/motif...  6.456251
#
#                                                 Markers
# 333   ZNF384,FANCC,ING4,XRCC5,CD2BP2,MRPS22,RMDN1,TP...
# 982   ZNF384,FANCC,ING4,XRCC5,CD2BP2,MRPS22,RMDN1,TP...
# 523   ZNF528,NPLOC4,ANKMY1,ZNF578,KNOP1,COG3,SLC25A4...
# 602   VPS25,ZNF384,NOSIP,TPRKB,NR1H2,TMEM167A,CCAR2,...
# 838   ADPRHL1,ZNF528,NPLOC4,ANKMY1,COG3,SLC25A46,ENT...
# ...                                                 ...
# 445   SLC25A33,MNT,NOD1,GEMIN8,TTYH1,RHOBTB3,CRIM1,C...
# 748   USP2,RAB23,RFX3,ANKRD9,C19orf12,AP5B1,MAPKAPK5...
# 280   RHPN1,NOL9,LINS1,NUP43,RAB23,CCHCR1,TRMO,ZNF61...
# 427   CARHSP1,ZNF621,CTSF,MFSD4A,C7orf26,GPSM1,AMER2...
# 1003  DAGLA,DCAF12,ANGPTL4,VPS11,PCED1A,ZNF569,MT2A,...
#
# [1618 rows x 7 columns]

# %%
# Look for main regulons
print("ATF4", "ATF4" in df.index.get_level_values('TF').values, sep="\t")
# Out:
# ATF4	True

# %% [markdown]
# ## Phase III: Cellular regulon enrichment matrix (aka AUCell)
#
# Characterize the different cells in a single-cell transcriptomics experiment by the enrichment of the regulons. Enrichment of a regulon is measures as AUC of the recovery curve of the genes that define this regulon.

# %%
auc_mtx = aucell(ex_matrix.transpose(), regulons, num_workers=param_n_workers)
auc_mtx.to_csv(f_regulons_aucell_path, sep = "\t")
auc_mtx
# Out:
# Regulon                     A1CF(+)  ABCF2(+)   ABL1(+)  ACAA1(+)   ACO1(+)  \
# Cell
# s.0096_AAACCCAAGTACGAGC.1  0.009444  0.000000  0.016985  0.020391  0.014743
# s.0096_AAACCCACACAGCGCT.1  0.038672  0.015596  0.028162  0.022865  0.015782
# s.0096_AAACCCACAGATAAAC.1  0.017409  0.004160  0.017414  0.016577  0.016254
# s.0096_AAACCCAGTCCGGATC.1  0.003260  0.000000  0.023215  0.007211  0.024733
# s.0096_AAACCCAGTCTCTCAC.1  0.001742  0.000000  0.016950  0.008251  0.013327
# ...                             ...       ...       ...       ...       ...
# s.0165_TTTGGTTTCCGCCTAT.1  0.010713  0.012080  0.024873  0.028892  0.035310
# s.0165_TTTGGTTTCTCGTTTA.1  0.028060  0.005654  0.026379  0.021684  0.028926
# s.0165_TTTGTTGCAAGTTCGT.1  0.006004  0.009323  0.027725  0.026777  0.017165
# s.0165_TTTGTTGCATGTTCAG.1  0.002247  0.000000  0.024487  0.034188  0.009337
# s.0165_TTTGTTGCATTACTCT.1  0.046007  0.000000  0.029104  0.023722  0.017920
#
# Regulon                    ADARB1(+)   ADNP(+)  ADNP2(+)  AEBP2(+)   AFF4(+)  \
# Cell
# s.0096_AAACCCAAGTACGAGC.1   0.019363  0.020046  0.026854  0.049865  0.044838
# s.0096_AAACCCACACAGCGCT.1   0.053353  0.025826  0.023695  0.079487  0.048850
# s.0096_AAACCCACAGATAAAC.1   0.038260  0.022193  0.021379  0.048196  0.043602
# s.0096_AAACCCAGTCCGGATC.1   0.026583  0.024318  0.019403  0.059641  0.045727
# s.0096_AAACCCAGTCTCTCAC.1   0.031233  0.026638  0.020131  0.070626  0.053468
# ...                              ...       ...       ...       ...       ...
# s.0165_TTTGGTTTCCGCCTAT.1   0.031963  0.032451  0.028849  0.045464  0.043862
# s.0165_TTTGGTTTCTCGTTTA.1   0.021650  0.025040  0.019235  0.031623  0.046157
# s.0165_TTTGTTGCAAGTTCGT.1   0.028448  0.027875  0.031789  0.054856  0.053299
# s.0165_TTTGTTGCATGTTCAG.1   0.027734  0.029019  0.015694  0.050122  0.047428
# s.0165_TTTGTTGCATTACTCT.1   0.033892  0.029891  0.024336  0.066295  0.038802
#
# Regulon                    ...  ZSCAN31(+)  ZSCAN32(+)  ZSCAN4(+)  ZSCAN5A(+)  \
# Cell                       ...
# s.0096_AAACCCAAGTACGAGC.1  ...    0.125639    0.000970   0.003486    0.015148
# s.0096_AAACCCACACAGCGCT.1  ...    0.037522    0.001408   0.016239    0.022776
# s.0096_AAACCCACAGATAAAC.1  ...    0.151181    0.003682   0.018529    0.019038
# s.0096_AAACCCAGTCCGGATC.1  ...    0.121864    0.003158   0.000000    0.023101
# s.0096_AAACCCAGTCTCTCAC.1  ...    0.133321    0.000701   0.004510    0.015616
# ...                        ...         ...         ...        ...         ...
# s.0165_TTTGGTTTCCGCCTAT.1  ...    0.136846    0.005627   0.000000    0.024579
# s.0165_TTTGGTTTCTCGTTTA.1  ...    0.055129    0.006968   0.019898    0.019863
# s.0165_TTTGTTGCAAGTTCGT.1  ...    0.087144    0.009686   0.033508    0.019337
# s.0165_TTTGTTGCATGTTCAG.1  ...    0.134554    0.012868   0.006077    0.013639
# s.0165_TTTGTTGCATTACTCT.1  ...    0.026396    0.016459   0.024115    0.032821
#
# Regulon                    ZSCAN5B(+)  ZSCAN9(+)  ZSWIM1(+)   ZXDA(+)  \
# Cell
# s.0096_AAACCCAAGTACGAGC.1    0.000000   0.007632   0.006456  0.030326
# s.0096_AAACCCACACAGCGCT.1    0.005076   0.005935   0.000000  0.016553
# s.0096_AAACCCACAGATAAAC.1    0.000811   0.004950   0.000000  0.012621
# s.0096_AAACCCAGTCCGGATC.1    0.000000   0.006347   0.000007  0.000000
# s.0096_AAACCCAGTCTCTCAC.1    0.000268   0.001830   0.002371  0.000000
# ...                               ...        ...        ...       ...
# s.0165_TTTGGTTTCCGCCTAT.1    0.024518   0.014054   0.001580  0.016065
# s.0165_TTTGGTTTCTCGTTTA.1    0.004099   0.010392   0.003524  0.024260
# s.0165_TTTGTTGCAAGTTCGT.1    0.003146   0.010351   0.000052  0.016027
# s.0165_TTTGTTGCATGTTCAG.1    0.074850   0.000802   0.012456  0.003955
# s.0165_TTTGTTGCATTACTCT.1    0.065527   0.014044   0.031858  0.004885
#
# Regulon                     ZXDB(+)   ZXDC(+)
# Cell
# s.0096_AAACCCAAGTACGAGC.1  0.001873  0.042951
# s.0096_AAACCCACACAGCGCT.1  0.003451  0.055055
# s.0096_AAACCCACAGATAAAC.1  0.000938  0.039366
# s.0096_AAACCCAGTCCGGATC.1  0.011583  0.035897
# s.0096_AAACCCAGTCTCTCAC.1  0.002785  0.038052
# ...                             ...       ...
# s.0165_TTTGGTTTCCGCCTAT.1  0.010628  0.042145
# s.0165_TTTGGTTTCTCGTTTA.1  0.009819  0.032126
# s.0165_TTTGTTGCAAGTTCGT.1  0.005154  0.045834
# s.0165_TTTGTTGCATGTTCAG.1  0.012222  0.034423
# s.0165_TTTGTTGCATTACTCT.1  0.014587  0.064399
#
# [83484 rows x 1618 columns]

# %%
# Checkpoint to regenerate the object from the file
#auc_mtx = pd.read_csv(f_regulons_aucell_path, sep = "\t", index_col = "Cell")
#auc_mtx.columns.name = "Regulon"
#auc_mtx

# %%
start = datetime.now(pytz.timezone('Europe/Paris'))
print("Start time:", start.strftime("%H:%M:%S"))

auc_mtx_bin = binarize(auc_mtx, seed = 42, num_workers=param_n_workers)

end = datetime.now(pytz.timezone('Europe/Paris'))
print("End time:", end.strftime("%H:%M:%S"))
print("Running time:", (end - start))

# Note: 04h21mn56 with num_workers=12
# Out:
# Start time: 13:28:23
# End time: 17:50:20
# Running time: 4:21:56.228980

# %%
binarization_thresholds = auc_mtx_bin[1]
binarization_thresholds.to_csv(f_regulons_binarization_thresholds_aucell_path, sep = "\t")
binarization_thresholds
# Out:
# Regulon
# A1CF(+)      0.022189
# ABCF2(+)     0.013607
# ABL1(+)      0.037242
# ACAA1(+)     0.038034
# ACO1(+)      0.044103
#                ...
# ZSCAN9(+)    0.018699
# ZSWIM1(+)    0.042951
# ZXDA(+)      0.014804
# ZXDB(+)      0.014456
# ZXDC(+)      0.059073
# Length: 1618, dtype: float64

# %%
auc_mtx_bin = auc_mtx_bin[0]
auc_mtx_bin.to_csv(f_regulons_binarized_aucell_path, sep = "\t")
auc_mtx_bin
# Out:
# Regulon                    A1CF(+)  ABCF2(+)  ABL1(+)  ACAA1(+)  ACO1(+)  \
# Cell
# s.0096_AAACCCAAGTACGAGC.1        0         0        0         0        0
# s.0096_AAACCCACACAGCGCT.1        1         1        0         0        0
# s.0096_AAACCCACAGATAAAC.1        0         0        0         0        0
# s.0096_AAACCCAGTCCGGATC.1        0         0        0         0        0
# s.0096_AAACCCAGTCTCTCAC.1        0         0        0         0        0
# ...                            ...       ...      ...       ...      ...
# s.0165_TTTGGTTTCCGCCTAT.1        0         0        0         0        0
# s.0165_TTTGGTTTCTCGTTTA.1        1         0        0         0        0
# s.0165_TTTGTTGCAAGTTCGT.1        0         0        0         0        0
# s.0165_TTTGTTGCATGTTCAG.1        0         0        0         0        0
# s.0165_TTTGTTGCATTACTCT.1        1         0        0         0        0
#
# Regulon                    ADARB1(+)  ADNP(+)  ADNP2(+)  AEBP2(+)  AFF4(+)  \
# Cell
# s.0096_AAACCCAAGTACGAGC.1          0        0         0         0        0
# s.0096_AAACCCACACAGCGCT.1          0        0         0         0        0
# s.0096_AAACCCACAGATAAAC.1          0        0         0         0        0
# s.0096_AAACCCAGTCCGGATC.1          0        0         0         0        0
# s.0096_AAACCCAGTCTCTCAC.1          0        0         0         0        0
# ...                              ...      ...       ...       ...      ...
# s.0165_TTTGGTTTCCGCCTAT.1          0        0         0         0        0
# s.0165_TTTGGTTTCTCGTTTA.1          0        0         0         0        0
# s.0165_TTTGTTGCAAGTTCGT.1          0        0         0         0        0
# s.0165_TTTGTTGCATGTTCAG.1          0        0         0         0        0
# s.0165_TTTGTTGCATTACTCT.1          0        0         0         0        0
#
# Regulon                    ...  ZSCAN31(+)  ZSCAN32(+)  ZSCAN4(+)  ZSCAN5A(+)  \
# Cell                       ...
# s.0096_AAACCCAAGTACGAGC.1  ...           1           0          0           0
# s.0096_AAACCCACACAGCGCT.1  ...           0           0          0           0
# s.0096_AAACCCACAGATAAAC.1  ...           1           0          1           0
# s.0096_AAACCCAGTCCGGATC.1  ...           1           0          0           0
# s.0096_AAACCCAGTCTCTCAC.1  ...           1           0          0           0
# ...                        ...         ...         ...        ...         ...
# s.0165_TTTGGTTTCCGCCTAT.1  ...           1           0          0           0
# s.0165_TTTGGTTTCTCGTTTA.1  ...           0           0          1           0
# s.0165_TTTGTTGCAAGTTCGT.1  ...           1           0          1           0
# s.0165_TTTGTTGCATGTTCAG.1  ...           1           0          0           0
# s.0165_TTTGTTGCATTACTCT.1  ...           0           1          1           0
#
# Regulon                    ZSCAN5B(+)  ZSCAN9(+)  ZSWIM1(+)  ZXDA(+)  ZXDB(+)  \
# Cell
# s.0096_AAACCCAAGTACGAGC.1           0          0          0        1        0
# s.0096_AAACCCACACAGCGCT.1           0          0          0        1        0
# s.0096_AAACCCACAGATAAAC.1           0          0          0        0        0
# s.0096_AAACCCAGTCCGGATC.1           0          0          0        0        0
# s.0096_AAACCCAGTCTCTCAC.1           0          0          0        0        0
# ...                               ...        ...        ...      ...      ...
# s.0165_TTTGGTTTCCGCCTAT.1           1          0          0        1        0
# s.0165_TTTGGTTTCTCGTTTA.1           0          0          0        1        0
# s.0165_TTTGTTGCAAGTTCGT.1           0          0          0        1        0
# s.0165_TTTGTTGCATGTTCAG.1           1          0          0        0        0
# s.0165_TTTGTTGCATTACTCT.1           1          0          0        0        1
#
# Regulon                    ZXDC(+)
# Cell
# s.0096_AAACCCAAGTACGAGC.1        0
# s.0096_AAACCCACACAGCGCT.1        0
# s.0096_AAACCCACAGATAAAC.1        0
# s.0096_AAACCCAGTCCGGATC.1        0
# s.0096_AAACCCAGTCTCTCAC.1        0
# ...                            ...
# s.0165_TTTGGTTTCCGCCTAT.1        0
# s.0165_TTTGGTTTCTCGTTTA.1        0
# s.0165_TTTGTTGCAAGTTCGT.1        0
# s.0165_TTTGTTGCATGTTCAG.1        0
# s.0165_TTTGTTGCATTACTCT.1        1
#
# [83484 rows x 1618 columns]

# %%
sum(auc_mtx_bin["ATF4(+)"])
# Out:
# 3886

# %%
binarization_thresholds.loc['ATF4(+)']
# Out:
# 0.06801822607244995

# %%
sum(auc_mtx["ATF4(+)"] > binarization_thresholds.loc['ATF4(+)'])
# Out:
# 3886
