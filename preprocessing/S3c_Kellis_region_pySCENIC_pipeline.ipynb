# %%
# !pip install anndata regdiffusion numpy==1.23.5
# I need anndata to load the h5ad file. Installing within the Docker...
# Out:
# Collecting anndata
#   Downloading anndata-0.11.4-py3-none-any.whl (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.5/144.5 kB 7.2 MB/s eta 0:00:00
# Collecting regdiffusion
#   Downloading regdiffusion-0.1.0-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: numpy==1.23.5 in /opt/venv/lib/python3.10/site-packages (1.23.5)
# Collecting packaging>=24.2
#   Downloading packaging-25.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 43.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas!=2.1.0rc0,!=2.1.2,>=1.4 in /opt/venv/lib/python3.10/site-packages (from anndata) (1.5.1)
# Requirement already satisfied: exceptiongroup in /opt/venv/lib/python3.10/site-packages (from anndata) (1.2.0)
# Requirement already satisfied: scipy>1.8 in /opt/venv/lib/python3.10/site-packages (from anndata) (1.9.3)
# Collecting array-api-compat!=1.5,>1.4
#   Downloading array_api_compat-1.11.2-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 35.3 MB/s eta 0:00:00
# Collecting natsort
#   Downloading natsort-8.4.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: h5py>=3.7 in /opt/venv/lib/python3.10/site-packages (from anndata) (3.7.0)
# Requirement already satisfied: scikit-learn in /opt/venv/lib/python3.10/site-packages (from regdiffusion) (1.1.3)
# Requirement already satisfied: tqdm in /opt/venv/lib/python3.10/site-packages (from regdiffusion) (4.64.1)
# Collecting torch
#   Downloading torch-2.7.0-cp310-cp310-manylinux_2_28_x86_64.whl (865.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 865.2/865.2 MB 5.0 MB/s eta 0:00:0000:0100:01
# Collecting scanpy
#   Downloading scanpy-1.11.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 26.0 MB/s eta 0:00:0000:0100:01
# Collecting pyvis
#   Downloading pyvis-0.3.2-py3-none-any.whl (756 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 14.3 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/venv/lib/python3.10/site-packages (from pandas!=2.1.0rc0,!=2.1.2,>=1.4->anndata) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/venv/lib/python3.10/site-packages (from pandas!=2.1.0rc0,!=2.1.2,>=1.4->anndata) (2022.6)
# Requirement already satisfied: jinja2>=2.9.6 in /opt/venv/lib/python3.10/site-packages (from pyvis->regdiffusion) (3.1.2)
# Requirement already satisfied: networkx>=1.11 in /opt/venv/lib/python3.10/site-packages (from pyvis->regdiffusion) (2.8.8)
# Requirement already satisfied: ipython>=5.3.0 in /opt/venv/lib/python3.10/site-packages (from pyvis->regdiffusion) (8.22.2)
# Collecting jsonpickle>=1.4.1
#   Downloading jsonpickle-4.0.5-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.4/46.4 kB 11.9 MB/s eta 0:00:00
# Collecting numba>=0.57
#   Downloading numba-0.61.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 7.3 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: umap-learn!=0.5.0,>=0.5 in /opt/venv/lib/python3.10/site-packages (from scanpy->regdiffusion) (0.5.3)
# Requirement already satisfied: pynndescent>=0.5 in /opt/venv/lib/python3.10/site-packages (from scanpy->regdiffusion) (0.5.8)
# Collecting statsmodels>=0.13
#   Downloading statsmodels-0.14.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 11.0 MB/s eta 0:00:0000:0100:01
# Collecting seaborn>=0.13
#   Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 14.0 MB/s eta 0:00:00
# Requirement already satisfied: joblib in /opt/venv/lib/python3.10/site-packages (from scanpy->regdiffusion) (1.2.0)
# Collecting matplotlib>=3.7
#   Downloading matplotlib-3.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 16.0 MB/s eta 0:00:0000:0100:01
# Collecting legacy-api-wrap>=1.4
#   Downloading legacy_api_wrap-1.4.1-py3-none-any.whl (10.0 kB)
# Collecting patsy!=1.0.0
#   Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.9/232.9 kB 20.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /opt/venv/lib/python3.10/site-packages (from scanpy->regdiffusion) (4.4.0)
# Collecting scanpy
#   Downloading scanpy-1.11.0-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 17.8 MB/s eta 0:00:0000:0100:01
#   Downloading scanpy-1.10.4-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 18.6 MB/s eta 0:00:0000:0100:01
# Collecting session-info
#   Downloading session_info-1.0.1-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: numba>=0.56 in /opt/venv/lib/python3.10/site-packages (from scanpy->regdiffusion) (0.56.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/venv/lib/python3.10/site-packages (from scikit-learn->regdiffusion) (3.1.0)
# Collecting nvidia-cuda-cupti-cu12==12.6.80
#   Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 20.8 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nccl-cu12==2.26.2
#   Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 12.4 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusparselt-cu12==0.6.3
#   Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 MB 19.8 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cufile-cu12==1.11.1.6
#   Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 54.8 MB/s eta 0:00:00
# Requirement already satisfied: fsspec in /opt/venv/lib/python3.10/site-packages (from torch->regdiffusion) (2022.11.0)
# Collecting triton==3.3.0
#   Downloading triton-3.3.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (156.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.4/156.4 MB 18.2 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cufft-cu12==11.3.0.4
#   Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 MB 14.1 MB/s eta 0:00:0000:0100:01
# Collecting typing-extensions>=4.10.0
#   Downloading typing_extensions-4.13.2-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 33.5 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.7.1.2
#   Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 MB 17.9 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-curand-cu12==10.3.7.77
#   Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 25.7 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77
#   Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 33.1 MB/s eta 0:00:0000:0100:01
# Collecting sympy>=1.13.3
#   Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 38.1 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nvjitlink-cu12==12.6.85
#   Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 39.4 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cublas-cu12==12.6.4.1
#   Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 5.0 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nvtx-cu12==12.6.77
#   Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.3/89.3 kB 7.6 MB/s eta 0:00:00
# Collecting filelock
#   Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17
#   Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.0/571.0 MB 5.2 MB/s eta 0:00:0000:0100:02
# Collecting nvidia-cusparse-cu12==12.5.4.2
#   Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 MB 12.1 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-runtime-cu12==12.6.77
#   Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 29.2 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=40.8.0 in /opt/venv/lib/python3.10/site-packages (from triton==3.3.0->torch->regdiffusion) (63.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in /opt/venv/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis->regdiffusion) (5.14.1)
# Requirement already satisfied: decorator in /opt/venv/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis->regdiffusion) (5.1.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/venv/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis->regdiffusion) (3.0.43)
# Requirement already satisfied: matplotlib-inline in /opt/venv/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis->regdiffusion) (0.1.6)
# Requirement already satisfied: jedi>=0.16 in /opt/venv/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis->regdiffusion) (0.19.1)
# Requirement already satisfied: stack-data in /opt/venv/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis->regdiffusion) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /opt/venv/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis->regdiffusion) (4.9.0)
# Requirement already satisfied: pygments>=2.4.0 in /opt/venv/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis->regdiffusion) (2.17.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/venv/lib/python3.10/site-packages (from jinja2>=2.9.6->pyvis->regdiffusion) (2.1.1)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.0/325.0 kB 29.8 MB/s eta 0:00:00
# Requirement already satisfied: pillow>=8 in /opt/venv/lib/python3.10/site-packages (from matplotlib>=3.7->scanpy->regdiffusion) (9.3.0)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.57.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 29.2 MB/s eta 0:00:0000:0100:01
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/venv/lib/python3.10/site-packages (from matplotlib>=3.7->scanpy->regdiffusion) (3.0.9)
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.8-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 30.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /opt/venv/lib/python3.10/site-packages (from numba>=0.56->scanpy->regdiffusion) (0.39.1)
# Requirement already satisfied: six>=1.5 in /opt/venv/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas!=2.1.0rc0,!=2.1.2,>=1.4->anndata) (1.16.0)
# Collecting mpmath<1.4,>=1.1.0
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 34.8 MB/s eta 0:00:00
# Collecting stdlib_list
#   Downloading stdlib_list-0.11.1-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.6/83.6 kB 20.9 MB/s eta 0:00:00
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/venv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis->regdiffusion) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/venv/lib/python3.10/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis->regdiffusion) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/venv/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis->regdiffusion) (0.2.13)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/venv/lib/python3.10/site-packages (from stack-data->ipython>=5.3.0->pyvis->regdiffusion) (2.4.1)
# Requirement already satisfied: executing>=1.2.0 in /opt/venv/lib/python3.10/site-packages (from stack-data->ipython>=5.3.0->pyvis->regdiffusion) (2.0.1)
# Requirement already satisfied: pure-eval in /opt/venv/lib/python3.10/site-packages (from stack-data->ipython>=5.3.0->pyvis->regdiffusion) (0.2.2)
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, typing-extensions, triton, sympy, stdlib_list, patsy, packaging, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, natsort, legacy-api-wrap, kiwisolver, jsonpickle, fonttools, filelock, cycler, contourpy, array-api-compat, session-info, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, matplotlib, statsmodels, seaborn, nvidia-cusolver-cu12, anndata, torch, pyvis, scanpy, regdiffusion
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.4.0
#     Uninstalling typing_extensions-4.4.0:
#       Successfully uninstalled typing_extensions-4.4.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# distributed 2022.11.1 requires tornado<6.2,>=6.0.3, but you have tornado 6.4 which is incompatible.
# Successfully installed anndata-0.11.4 array-api-compat-1.11.2 contourpy-1.3.2 cycler-0.12.1 filelock-3.18.0 fonttools-4.57.0 jsonpickle-4.0.5 kiwisolver-1.4.8 legacy-api-wrap-1.4.1 matplotlib-3.10.3 mpmath-1.3.0 natsort-8.4.0 nvidia-cublas-cu12-12.6.4.1 nvidia-cuda-cupti-cu12-12.6.80 nvidia-cuda-nvrtc-cu12-12.6.77 nvidia-cuda-runtime-cu12-12.6.77 nvidia-cudnn-cu12-9.5.1.17 nvidia-cufft-cu12-11.3.0.4 nvidia-cufile-cu12-1.11.1.6 nvidia-curand-cu12-10.3.7.77 nvidia-cusolver-cu12-11.7.1.2 nvidia-cusparse-cu12-12.5.4.2 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 nvidia-nvjitlink-cu12-12.6.85 nvidia-nvtx-cu12-12.6.77 packaging-25.0 patsy-1.0.1 pyvis-0.3.2 regdiffusion-0.1.0 scanpy-1.10.4 seaborn-0.13.2 session-info-1.0.1 statsmodels-0.14.4 stdlib_list-0.11.1 sympy-1.14.0 torch-2.7.0 triton-3.3.0 typing-extensions-4.13.2
#
# [notice] A new release of pip available: 22.2.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
# Fix OPENBLAS Warnings
import os
param_n_workers = 64 # We have 112 CPUs/cores, each process will automatically be associated to a different CPU by the OS scheduler
param_threads_per_worker=2 # We have 2 threads per CPU on SVEN (hyper-threading). See lscpu command. Note: Here they are not used apparently. Setting to 1 or 2 gives similar c. time
os.environ['OPENBLAS_NUM_THREADS'] = f"{param_n_workers * param_threads_per_worker}"
os.environ['MKL_NUM_THREADS'] = f"{param_n_workers * param_threads_per_worker}"
os.environ['OMP_NUM_THREADS'] = f"{param_n_workers * param_threads_per_worker}"
os.environ['NUMEXPR_MAX_THREADS'] = f"{param_n_workers * param_threads_per_worker}"

# import dependencies
import pandas as pd
import numpy as np
import regdiffusion as rd # For replacing grnboost2 which is slow as hell and bugs (stalls) when there are more than ~1.5B elements in the matrix
import pickle
import pytz

from datetime import datetime
from arboreto.utils import load_tf_names
from arboreto.algo import grnboost2
from distributed import Client, LocalCluster

from ctxcore.rnkdb import FeatherRankingDatabase as RankingDatabase
from pyscenic.binarization import binarize
from pyscenic.utils import modules_from_adjacencies
from pyscenic.prune import prune2df, df2regulons
from pyscenic.aucell import aucell

from scipy.sparse import csr_matrix
from scipy.io import mmwrite, mmread

# %%
import anndata as ad

# [Input] H5ad file to use
#EXPRESSION_H5AD_FNAME = '/data/gardeux/Neuro_Droso_ND75KD/data/Kellis_2024/Gene Expression (snRNAseq - 10x) processed/PFC427_raw_data.h5ad' # From Synapse
EXPRESSION_H5AD_FNAME = '/data/gardeux/Neuro_Droso_ND75KD/data/Kellis_2024/Gene Expression (snRNAseq - 10x) processed, multi-region/all_brain_regions_filt_preprocessed_scanpy_fullmatrix.h5ad' # From Synapse
METADATA_H5AD_FNAME = "/data/gardeux/Neuro_Droso_ND75KD/data/Kellis_2024/Gene Expression (snRNAseq - 10x) processed, multi-region/all_brain_regions_filt_preprocessed_scanpy_norm.final_noMB.cell_labels.tsv"

# [Input] Load expression matrix from H5ad file
f_h5ad = ad.read_h5ad(EXPRESSION_H5AD_FNAME)
f_gene_names = f_h5ad.var_names.tolist()  # Gene names
f_cell_names = f_h5ad.obs_names.tolist()   # Cell names
ex_matrix = pd.DataFrame.sparse.from_spmatrix(f_h5ad.X.T, index=f_gene_names, columns=f_cell_names)

# [Output]
param_mtx_file = "/data/gardeux/Neuro_Droso_ND75KD/data/Kellis_2024/Gene Expression (snRNAseq - 10x) processed, multi-region/all_brain_regions_filt_preprocessed_scanpy_fullmatrix_excitatory.neurons.only.mtx"
param_features_file = "/data/gardeux/Neuro_Droso_ND75KD/data/Kellis_2024/Gene Expression (snRNAseq - 10x) processed, multi-region/features.tsv"
param_barcodes_file = "/data/gardeux/Neuro_Droso_ND75KD/data/Kellis_2024/Gene Expression (snRNAseq - 10x) processed, multi-region/barcodes.tsv"

# [Input] Transcription factors list (SCENIC step 1: GRNBoost2)
f_tfs = "/data/gardeux/Neuro_Droso_ND75KD/data/allTFs_hg38.txt" # From https://resources.aertslab.org/cistarget/tf_lists/
# Derive list of Transcription Factors(TF)
tf_names = load_tf_names(f_tfs)

# [Output] Adjacency matrix (SCENIC step 1: GRNBoost2)
adj_matrix = "/data/gardeux/Neuro_Droso_ND75KD/data/Kellis_2024/Kellis_region_adj.csv"

# [Input] Ranking databases (SCENIC step 2-3: cisTarget)
f_db_names = ["/data/gardeux/Neuro_Droso_ND75KD/data/hg38_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings.feather"] # From pySCENIC db: https://resources.aertslab.org/cistarget/databases/homo_sapiens/hg38/refseq_r80/mc_v10_clust/gene_based/
# Alternatively: f_db_names = ["/data/gardeux/Neuro_Droso_ND75KD/data/hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings.feather"]
dbs = [RankingDatabase(fname=f_name, name=os.path.basename(f_name)) for f_name in f_db_names]

# [Input] Motif databases (SCENIC step 2-3: cisTarget)
f_motif_path = "/data/gardeux/Neuro_Droso_ND75KD/data/motifs-v10nr_clust-nr.hgnc-m0.001-o0.0.tbl" # From pySCENIC db: https://resources.aertslab.org/cistarget/motif2tf/

# [Output] Regulons (SCENIC step 2-3: cisTarget)
f_motifs_path = "/data/gardeux/Neuro_Droso_ND75KD/data/Kellis_2024/Kellis_region_motifs.tsv"
f_modules_path = "/data/gardeux/Neuro_Droso_ND75KD/data/Kellis_2024/Kellis_region_modules.tsv"
f_regulons_path = "/data/gardeux/Neuro_Droso_ND75KD/data/Kellis_2024/Kellis_region_regulons.tsv"
f_regulons_aucell_path = "/data/gardeux/Neuro_Droso_ND75KD/data/Kellis_2024/Kellis_region_regulons_aucell.tsv"
f_regulons_binarized_aucell_path = "/data/gardeux/Neuro_Droso_ND75KD/data/Kellis_2024/Kellis_region_regulons_aucell_binarized.tsv"
f_regulons_binarization_thresholds_aucell_path = "/data/gardeux/Neuro_Droso_ND75KD/data/Kellis_2024/Kellis_region_regulons_aucell_binarization_thresholds.tsv"

# Restrict matrix to feather genes
ranking_feather = pd.read_feather(f_db_names[0])
overlap_values = ex_matrix.index[pd.Series(ex_matrix.index).isin(ranking_feather.columns)].unique()
ex_matrix = ex_matrix.loc[overlap_values, :] # This step takes forever

ex_matrix # 18587 (out of XXX) genes x 1612073 cells for region data  # 20653 (out of 33538) genes x 2663736 cells for cell_type data
# Out:
#           AG_AAACCCACAGATAAAC-1  AG_AAACGAAAGGCCACCT-1  AG_AAACGAACACAAATAG-1  \
# OR4F5                       0.0                    0.0                    0.0
# OR4F29                      0.0                    0.0                    0.0
# OR4F16                      0.0                    0.0                    0.0
# SAMD11                      0.0                    0.0                    0.0
# NOC2L                       0.0                    0.0                    0.0
# ...                         ...                    ...                    ...
# C21orf58                    0.0                    0.0                    0.0
# PCNT                        2.0                    0.0                    2.0
# DIP2A                       0.0                    1.0                    1.0
# S100B                       0.0                    0.0                    0.0
# PRMT2                       0.0                    1.0                    0.0
#
#           AG_AAACGAATCCACAGGC-1  AG_AAACGCTCAAACACGG-1  AG_AAACGCTCAGAATCGG-1  \
# OR4F5                       0.0                    0.0                    0.0
# OR4F29                      0.0                    0.0                    0.0
# OR4F16                      0.0                    0.0                    0.0
# SAMD11                      0.0                    0.0                    0.0
# NOC2L                       1.0                    0.0                    1.0
# ...                         ...                    ...                    ...
# C21orf58                    0.0                    0.0                    0.0
# PCNT                        2.0                    0.0                    0.0
# DIP2A                      11.0                    0.0                    1.0
# S100B                       0.0                    1.0                    0.0
# PRMT2                       0.0                    0.0                    1.0
#
#           AG_AAACGCTTCTGTTCAT-1  AG_AAAGGGCAGCTAATGA-1  AG_AAAGGGCTCGCTTGAA-1  \
# OR4F5                       0.0                    0.0                    0.0
# OR4F29                      0.0                    0.0                    0.0
# OR4F16                      0.0                    0.0                    0.0
# SAMD11                      0.0                    0.0                    0.0
# NOC2L                       0.0                    0.0                    2.0
# ...                         ...                    ...                    ...
# C21orf58                    0.0                    0.0                    0.0
# PCNT                        1.0                    0.0                    1.0
# DIP2A                       1.0                    1.0                    5.0
# S100B                       0.0                    0.0                    0.0
# PRMT2                       0.0                    1.0                    4.0
#
#           AG_AAAGGTACAGACCCGT-1  ...  TH_TTTGACTGTGCCTAAT-47  \
# OR4F5                       0.0  ...                     0.0
# OR4F29                      0.0  ...                     0.0
# OR4F16                      0.0  ...                     0.0
# SAMD11                      0.0  ...                     0.0
# NOC2L                       0.0  ...                     0.0
# ...                         ...  ...                     ...
# C21orf58                    0.0  ...                     0.0
# PCNT                        0.0  ...                     0.0
# DIP2A                       0.0  ...                     2.0
# S100B                       0.0  ...                     0.0
# PRMT2                       0.0  ...                     2.0
#
#           TH_TTTGATCAGCAAATGT-47  TH_TTTGGAGAGCTAGATA-47  \
# OR4F5                        0.0                     0.0
# OR4F29                       0.0                     0.0
# OR4F16                       0.0                     0.0
# SAMD11                       0.0                     0.0
# NOC2L                        0.0                     0.0
# ...                          ...                     ...
# C21orf58                     0.0                     0.0
# PCNT                         1.0                     0.0
# DIP2A                        0.0                     0.0
# S100B                        0.0                     0.0
# PRMT2                        1.0                     2.0
#
#           TH_TTTGGAGGTCTCCCTA-47  TH_TTTGGAGTCATTTCGT-47  \
# OR4F5                        0.0                     0.0
# OR4F29                       0.0                     0.0
# OR4F16                       0.0                     0.0
# SAMD11                       0.0                     0.0
# NOC2L                        0.0                     0.0
# ...                          ...                     ...
# C21orf58                     0.0                     0.0
# PCNT                         0.0                     0.0
# DIP2A                        2.0                     3.0
# S100B                        0.0                     0.0
# PRMT2                        0.0                     1.0
#
#           TH_TTTGGTTAGTACAGCG-47  TH_TTTGGTTGTTACAGCT-47  \
# OR4F5                        0.0                     0.0
# OR4F29                       0.0                     0.0
# OR4F16                       0.0                     0.0
# SAMD11                       0.0                     0.0
# NOC2L                        0.0                     0.0
# ...                          ...                     ...
# C21orf58                     0.0                     0.0
# PCNT                         0.0                     0.0
# DIP2A                        0.0                     0.0
# S100B                        0.0                     0.0
# PRMT2                        1.0                     0.0
#
#           TH_TTTGTTGCACCTCTGT-47  TH_TTTGTTGGTATGCTAC-47  \
# OR4F5                        0.0                     0.0
# OR4F29                       0.0                     0.0
# OR4F16                       0.0                     0.0
# SAMD11                       0.0                     0.0
# NOC2L                        0.0                     0.0
# ...                          ...                     ...
# C21orf58                     0.0                     0.0
# PCNT                         0.0                     0.0
# DIP2A                        1.0                     0.0
# S100B                        0.0                     1.0
# PRMT2                        0.0                     0.0
#
#           TH_TTTGTTGGTCGGATTT-47
# OR4F5                        0.0
# OR4F29                       0.0
# OR4F16                       0.0
# SAMD11                       0.0
# NOC2L                        0.0
# ...                          ...
# C21orf58                     0.0
# PCNT                         0.0
# DIP2A                        0.0
# S100B                        1.0
# PRMT2                        0.0
#
# [18587 rows x 1612073 columns]

# %%
# Safety check
(f_h5ad.obs.index == ex_matrix.columns).all()
# Out:
# True

# %%
# Import metadata from file
metadata = pd.read_csv(METADATA_H5AD_FNAME, index_col=0, sep = "\t", low_memory=False)  # Assuming first column is the cell ID
metadata = metadata.set_index("barcode")
metadata
# Out:
#                               U1         U2   rind region    projid  \
# barcode
# AG_AACCATGTCATTGCGA-1  -2.428250   8.324310   AG.1     AG  50410319
# AG_AACGGGATCGAGATGG-1  -5.414470  12.086900   AG.1     AG  50410319
# AG_AACGTCAAGCGTGAAC-1  -2.404900  10.881300   AG.1     AG  50410319
# AG_AAGCGAGAGGACAAGA-1  -5.492280  13.338700   AG.1     AG  50410319
# AG_AAGGTAACATGGGATG-1  -3.846350  12.626400   AG.1     AG  50410319
# ...                          ...        ...    ...    ...       ...
# TH_TTGCCTGGTACATACC-47  0.669809   5.040410  TH.47     TH  94430339
# TH_TTGGGATTCAACACGT-47  5.291230   0.209286  TH.47     TH  94430339
# TH_TTGGGTAAGAGAGAAC-47  3.646170   0.957303  TH.47     TH  94430339
# TH_TTGTGTTGTCACGACC-47  0.820165   4.782530  TH.47     TH  94430339
# TH_TTTATGCGTACCGGCT-47  0.665545   4.990100  TH.47     TH  94430339
#
#                         is.doublet      col     tspcol  \
# barcode
# AG_AACCATGTCATTGCGA-1        False  #E31A1C  #E31A1C80
# AG_AACGGGATCGAGATGG-1        False  #E31A1C  #E31A1C80
# AG_AACGTCAAGCGTGAAC-1        False  #E31A1C  #E31A1C80
# AG_AAGCGAGAGGACAAGA-1        False  #E31A1C  #E31A1C80
# AG_AAGGTAACATGGGATG-1        False  #E31A1C  #E31A1C80
# ...                            ...      ...        ...
# TH_TTGCCTGGTACATACC-47       False  #FED9A6  #FED9A680
# TH_TTGGGATTCAACACGT-47       False  #FED9A6  #1F78B480
# TH_TTGGGTAAGAGAGAAC-47       False  #FED9A6  #FED9A680
# TH_TTGTGTTGTCACGACC-47       False  #FED9A6  #FED9A680
# TH_TTTATGCGTACCGGCT-47       False  #FED9A6  #FED9A680
#
#                                                hcluster       hcelltype  \
# barcode
# AG_AACCATGTCATTGCGA-1                               NaN             Ast
# AG_AACGGGATCGAGATGG-1                               NaN             Ast
# AG_AACGTCAAGCGTGAAC-1                               NaN             Ast
# AG_AAGCGAGAGGACAAGA-1                               NaN             Ast
# AG_AAGGTAACATGGGATG-1                               NaN             Ast
# ...                                                 ...             ...
# TH_TTGCCTGGTACATACC-47  choroid_plexus_epithelial_cells  Vasc/Epithelia
# TH_TTGGGATTCAACACGT-47                endothelial_cells  Vasc/Epithelia
# TH_TTGGGTAAGAGAGAAC-47                      fibroblasts  Vasc/Epithelia
# TH_TTGTGTTGTCACGACC-47  choroid_plexus_epithelial_cells  Vasc/Epithelia
# TH_TTTATGCGTACCGGCT-47  choroid_plexus_epithelial_cells  Vasc/Epithelia
#
#                        hsubclass  major.celltype minor.celltype  \
# barcode
# AG_AACCATGTCATTGCGA-1        NaN             Ast            Ast
# AG_AACGGGATCGAGATGG-1        NaN             Ast            Ast
# AG_AACGTCAAGCGTGAAC-1        NaN             Ast            Ast
# AG_AAGCGAGAGGACAAGA-1        NaN             Ast            Ast
# AG_AAGGTAACATGGGATG-1        NaN             Ast            Ast
# ...                          ...             ...            ...
# TH_TTGCCTGGTACATACC-47       NaN  Vasc/Epithelia           CPEC
# TH_TTGGGATTCAACACGT-47       NaN  Vasc/Epithelia            End
# TH_TTGGGTAAGAGAGAAC-47       NaN  Vasc/Epithelia            Fib
# TH_TTGTGTTGTCACGACC-47       NaN  Vasc/Epithelia           CPEC
# TH_TTTATGCGTACCGGCT-47       NaN  Vasc/Epithelia           CPEC
#
#                        neuronal.layer inh.subtype neuronal.exttype  \
# barcode
# AG_AACCATGTCATTGCGA-1             NaN         NaN              NaN
# AG_AACGGGATCGAGATGG-1             NaN         NaN              NaN
# AG_AACGTCAAGCGTGAAC-1             NaN         NaN              NaN
# AG_AAGCGAGAGGACAAGA-1             NaN         NaN              NaN
# AG_AAGGTAACATGGGATG-1             NaN         NaN              NaN
# ...                               ...         ...              ...
# TH_TTGCCTGGTACATACC-47            NaN         NaN              NaN
# TH_TTGGGATTCAACACGT-47            NaN         NaN              NaN
# TH_TTGGGTAAGAGAGAAC-47            NaN         NaN              NaN
# TH_TTGTGTTGTCACGACC-47            NaN         NaN              NaN
# TH_TTTATGCGTACCGGCT-47            NaN         NaN              NaN
#
#                        full.exttype cell_type_high_resolution
# barcode
# AG_AACCATGTCATTGCGA-1           Ast                 Ast DPP10
# AG_AACGGGATCGAGATGG-1           Ast                  Ast GRM3
# AG_AACGTCAAGCGTGAAC-1           Ast                  Ast GRM3
# AG_AAGCGAGAGGACAAGA-1           Ast                  Ast GRM3
# AG_AAGGTAACATGGGATG-1           Ast                  Ast GRM3
# ...                             ...                       ...
# TH_TTGCCTGGTACATACC-47         CPEC                      CPEC
# TH_TTGGGATTCAACACGT-47          End                       End
# TH_TTGGGTAAGAGAGAAC-47          Fib                       Fib
# TH_TTGTGTTGTCACGACC-47         CPEC                      CPEC
# TH_TTTATGCGTACCGGCT-47         CPEC                      CPEC
#
# [1353075 rows x 18 columns]

# %%
# Filter ex_matrix object
ex_matrix = ex_matrix.loc[:, ex_matrix.columns.isin(metadata.index)]
ex_matrix
# Out:
#           AG_AAACCCACAGATAAAC-1  AG_AAACGAAAGGCCACCT-1  AG_AAACGAACACAAATAG-1  \
# OR4F5                       0.0                    0.0                    0.0
# OR4F29                      0.0                    0.0                    0.0
# OR4F16                      0.0                    0.0                    0.0
# SAMD11                      0.0                    0.0                    0.0
# NOC2L                       0.0                    0.0                    0.0
# ...                         ...                    ...                    ...
# C21orf58                    0.0                    0.0                    0.0
# PCNT                        2.0                    0.0                    2.0
# DIP2A                       0.0                    1.0                    1.0
# S100B                       0.0                    0.0                    0.0
# PRMT2                       0.0                    1.0                    0.0
#
#           AG_AAACGAATCCACAGGC-1  AG_AAACGCTCAAACACGG-1  AG_AAACGCTCAGAATCGG-1  \
# OR4F5                       0.0                    0.0                    0.0
# OR4F29                      0.0                    0.0                    0.0
# OR4F16                      0.0                    0.0                    0.0
# SAMD11                      0.0                    0.0                    0.0
# NOC2L                       1.0                    0.0                    1.0
# ...                         ...                    ...                    ...
# C21orf58                    0.0                    0.0                    0.0
# PCNT                        2.0                    0.0                    0.0
# DIP2A                      11.0                    0.0                    1.0
# S100B                       0.0                    1.0                    0.0
# PRMT2                       0.0                    0.0                    1.0
#
#           AG_AAACGCTTCTGTTCAT-1  AG_AAAGGGCAGCTAATGA-1  AG_AAAGGGCTCGCTTGAA-1  \
# OR4F5                       0.0                    0.0                    0.0
# OR4F29                      0.0                    0.0                    0.0
# OR4F16                      0.0                    0.0                    0.0
# SAMD11                      0.0                    0.0                    0.0
# NOC2L                       0.0                    0.0                    2.0
# ...                         ...                    ...                    ...
# C21orf58                    0.0                    0.0                    0.0
# PCNT                        1.0                    0.0                    1.0
# DIP2A                       1.0                    1.0                    5.0
# S100B                       0.0                    0.0                    0.0
# PRMT2                       0.0                    1.0                    4.0
#
#           AG_AAAGGTACAGACCCGT-1  ...  TH_TTTGACTGTGCCTAAT-47  \
# OR4F5                       0.0  ...                     0.0
# OR4F29                      0.0  ...                     0.0
# OR4F16                      0.0  ...                     0.0
# SAMD11                      0.0  ...                     0.0
# NOC2L                       0.0  ...                     0.0
# ...                         ...  ...                     ...
# C21orf58                    0.0  ...                     0.0
# PCNT                        0.0  ...                     0.0
# DIP2A                       0.0  ...                     2.0
# S100B                       0.0  ...                     0.0
# PRMT2                       0.0  ...                     2.0
#
#           TH_TTTGATCAGCAAATGT-47  TH_TTTGGAGAGCTAGATA-47  \
# OR4F5                        0.0                     0.0
# OR4F29                       0.0                     0.0
# OR4F16                       0.0                     0.0
# SAMD11                       0.0                     0.0
# NOC2L                        0.0                     0.0
# ...                          ...                     ...
# C21orf58                     0.0                     0.0
# PCNT                         1.0                     0.0
# DIP2A                        0.0                     0.0
# S100B                        0.0                     0.0
# PRMT2                        1.0                     2.0
#
#           TH_TTTGGAGGTCTCCCTA-47  TH_TTTGGAGTCATTTCGT-47  \
# OR4F5                        0.0                     0.0
# OR4F29                       0.0                     0.0
# OR4F16                       0.0                     0.0
# SAMD11                       0.0                     0.0
# NOC2L                        0.0                     0.0
# ...                          ...                     ...
# C21orf58                     0.0                     0.0
# PCNT                         0.0                     0.0
# DIP2A                        2.0                     3.0
# S100B                        0.0                     0.0
# PRMT2                        0.0                     1.0
#
#           TH_TTTGGTTAGTACAGCG-47  TH_TTTGGTTGTTACAGCT-47  \
# OR4F5                        0.0                     0.0
# OR4F29                       0.0                     0.0
# OR4F16                       0.0                     0.0
# SAMD11                       0.0                     0.0
# NOC2L                        0.0                     0.0
# ...                          ...                     ...
# C21orf58                     0.0                     0.0
# PCNT                         0.0                     0.0
# DIP2A                        0.0                     0.0
# S100B                        0.0                     0.0
# PRMT2                        1.0                     0.0
#
#           TH_TTTGTTGCACCTCTGT-47  TH_TTTGTTGGTATGCTAC-47  \
# OR4F5                        0.0                     0.0
# OR4F29                       0.0                     0.0
# OR4F16                       0.0                     0.0
# SAMD11                       0.0                     0.0
# NOC2L                        0.0                     0.0
# ...                          ...                     ...
# C21orf58                     0.0                     0.0
# PCNT                         0.0                     0.0
# DIP2A                        1.0                     0.0
# S100B                        0.0                     1.0
# PRMT2                        0.0                     0.0
#
#           TH_TTTGTTGGTCGGATTT-47
# OR4F5                        0.0
# OR4F29                       0.0
# OR4F16                       0.0
# SAMD11                       0.0
# NOC2L                        0.0
# ...                          ...
# C21orf58                     0.0
# PCNT                         0.0
# DIP2A                        0.0
# S100B                        1.0
# PRMT2                        0.0
#
# [18587 rows x 1353075 columns]

# %%
# Reorder
metadata = metadata.sort_index()
ex_matrix = ex_matrix.reindex(sorted(ex_matrix.columns), axis=1)

# %%
# Safety check
(metadata.index == ex_matrix.columns).all()
# Out:
# True

# %%
# Subset to only Excitatory neurons
ex_matrix = ex_matrix.loc[:, metadata["major.celltype"] == "Exc"]
ex_matrix # 18587 rows (genes) × 436014 columns (cells)
# Out:
#           AG_AAACCCAAGAAATTCG-40  AG_AAACCCAAGACAACTA-20  \
# OR4F5                        0.0                     0.0
# OR4F29                       0.0                     0.0
# OR4F16                       0.0                     0.0
# SAMD11                       0.0                     0.0
# NOC2L                        0.0                     0.0
# ...                          ...                     ...
# C21orf58                     0.0                     0.0
# PCNT                         6.0                     2.0
# DIP2A                        0.0                     1.0
# S100B                        0.0                     0.0
# PRMT2                        0.0                     0.0
#
#           AG_AAACCCAAGACCACGA-45  AG_AAACCCAAGACCTCCG-24  \
# OR4F5                        0.0                     0.0
# OR4F29                       0.0                     0.0
# OR4F16                       0.0                     0.0
# SAMD11                       0.0                     0.0
# NOC2L                        1.0                     0.0
# ...                          ...                     ...
# C21orf58                     0.0                     0.0
# PCNT                         4.0                     1.0
# DIP2A                        2.0                     0.0
# S100B                        0.0                     0.0
# PRMT2                        1.0                     0.0
#
#           AG_AAACCCAAGAGAGGTA-18  AG_AAACCCAAGAGGTCAC-45  \
# OR4F5                        0.0                     0.0
# OR4F29                       0.0                     0.0
# OR4F16                       0.0                     0.0
# SAMD11                       0.0                     0.0
# NOC2L                        0.0                     0.0
# ...                          ...                     ...
# C21orf58                     0.0                     0.0
# PCNT                         0.0                     0.0
# DIP2A                        0.0                     0.0
# S100B                        0.0                     0.0
# PRMT2                        0.0                     0.0
#
#           AG_AAACCCAAGAGTGACC-41  AG_AAACCCAAGATGAACT-38  \
# OR4F5                        0.0                     0.0
# OR4F29                       0.0                     0.0
# OR4F16                       0.0                     0.0
# SAMD11                       0.0                     0.0
# NOC2L                        1.0                     0.0
# ...                          ...                     ...
# C21orf58                     0.0                     0.0
# PCNT                         1.0                     0.0
# DIP2A                        0.0                     0.0
# S100B                        0.0                     0.0
# PRMT2                        3.0                     1.0
#
#           AG_AAACCCAAGATTAGCA-14  AG_AAACCCAAGATTAGCA-23  ...  \
# OR4F5                        0.0                     0.0  ...
# OR4F29                       0.0                     0.0  ...
# OR4F16                       0.0                     0.0  ...
# SAMD11                       0.0                     0.0  ...
# NOC2L                        0.0                     0.0  ...
# ...                          ...                     ...  ...
# C21orf58                     0.0                     1.0  ...
# PCNT                         0.0                     0.0  ...
# DIP2A                        2.0                     0.0  ...
# S100B                        0.0                     0.0  ...
# PRMT2                        0.0                     1.0  ...
#
#           TH_TTTGTTGTCAACCCGG-41  TH_TTTGTTGTCACCCTCA-12  \
# OR4F5                        0.0                     0.0
# OR4F29                       0.0                     0.0
# OR4F16                       0.0                     0.0
# SAMD11                       0.0                     0.0
# NOC2L                        0.0                     1.0
# ...                          ...                     ...
# C21orf58                     0.0                     0.0
# PCNT                         0.0                     1.0
# DIP2A                        0.0                     4.0
# S100B                        0.0                     0.0
# PRMT2                        1.0                     1.0
#
#           TH_TTTGTTGTCACTTGTT-17  TH_TTTGTTGTCCAATCTT-29  \
# OR4F5                        0.0                     0.0
# OR4F29                       0.0                     0.0
# OR4F16                       0.0                     0.0
# SAMD11                       0.0                     0.0
# NOC2L                        0.0                     0.0
# ...                          ...                     ...
# C21orf58                     0.0                     0.0
# PCNT                         0.0                     0.0
# DIP2A                        1.0                     0.0
# S100B                        0.0                     0.0
# PRMT2                        0.0                     0.0
#
#           TH_TTTGTTGTCCAATCTT-32  TH_TTTGTTGTCGAACCAT-29  \
# OR4F5                        0.0                     0.0
# OR4F29                       0.0                     0.0
# OR4F16                       0.0                     0.0
# SAMD11                       0.0                     0.0
# NOC2L                        0.0                     1.0
# ...                          ...                     ...
# C21orf58                     0.0                     0.0
# PCNT                         6.0                     0.0
# DIP2A                        9.0                     0.0
# S100B                        0.0                     0.0
# PRMT2                        6.0                     0.0
#
#           TH_TTTGTTGTCGAACCAT-32  TH_TTTGTTGTCGGAGTAG-32  \
# OR4F5                        0.0                     0.0
# OR4F29                       0.0                     0.0
# OR4F16                       0.0                     0.0
# SAMD11                       0.0                     0.0
# NOC2L                        1.0                     1.0
# ...                          ...                     ...
# C21orf58                     0.0                     0.0
# PCNT                         5.0                     1.0
# DIP2A                        6.0                     4.0
# S100B                        0.0                     0.0
# PRMT2                        7.0                     2.0
#
#           TH_TTTGTTGTCTCGTTTA-9  TH_TTTGTTGTCTTGAACG-22
# OR4F5                       0.0                     0.0
# OR4F29                      0.0                     0.0
# OR4F16                      0.0                     0.0
# SAMD11                      0.0                     0.0
# NOC2L                       0.0                     0.0
# ...                         ...                     ...
# C21orf58                    0.0                     0.0
# PCNT                        2.0                     0.0
# DIP2A                       0.0                     0.0
# S100B                       0.0                     0.0
# PRMT2                       3.0                     0.0
#
# [18587 rows x 436014 columns]

# %% [markdown]
# # SCENIC steps
#
# ## STEP 1: Gene regulatory network inference, and generation of co-expression modules
#
# ### 1.a. GRN inference using the GRNBoost2 algorithm
#
# In the initial phase of the pySCENIC pipeline the single cell expression profiles are used to infer co-expression modules from.
#
# Run GRNboost from arboreto to infer co-expression modules
#
# The arboreto package is used for this phase of the pipeline.
#
# *Output:* List of adjacencies between a TF and its targets.

# %% [markdown]
# Run RegDiffusionTrainer instead of the (slow) GRNBoost2 algorithm. See https://tuftsbcb.github.io/RegDiffusion/downstream_with_pyscenic.html

# %%
# Prepare dataset for RegDiffusionTrainer (needs to be logged, cells as rows)
ex_matrix = np.log(ex_matrix.transpose() + 1.0) # Transpose and log
gene_names = ex_matrix.columns
ex_matrix = ex_matrix.loc[:, ~(ex_matrix == 0).all()] # Drop columns where all values are 0
ex_matrix
# Out:
#                         OR4F5  SAMD11     NOC2L  KLHL17  PLEKHN1  PERM1  \
# AG_AAACCCAAGAAATTCG-40    0.0     0.0  0.000000     0.0      0.0    0.0
# AG_AAACCCAAGACAACTA-20    0.0     0.0  0.000000     0.0      0.0    0.0
# AG_AAACCCAAGACCACGA-45    0.0     0.0  0.693147     0.0      0.0    0.0
# AG_AAACCCAAGACCTCCG-24    0.0     0.0  0.000000     0.0      0.0    0.0
# AG_AAACCCAAGAGAGGTA-18    0.0     0.0  0.000000     0.0      0.0    0.0
# ...                       ...     ...       ...     ...      ...    ...
# TH_TTTGTTGTCGAACCAT-29    0.0     0.0  0.693147     0.0      0.0    0.0
# TH_TTTGTTGTCGAACCAT-32    0.0     0.0  0.693147     0.0      0.0    0.0
# TH_TTTGTTGTCGGAGTAG-32    0.0     0.0  0.693147     0.0      0.0    0.0
# TH_TTTGTTGTCTCGTTTA-9     0.0     0.0  0.000000     0.0      0.0    0.0
# TH_TTTGTTGTCTTGAACG-22    0.0     0.0  0.000000     0.0      0.0    0.0
#
#                             HES4     ISG15      AGRN  RNF223  ...      FTCD  \
# AG_AAACCCAAGAAATTCG-40  0.000000  0.000000  1.609438     0.0  ...  0.693147
# AG_AAACCCAAGACAACTA-20  0.000000  0.000000  0.000000     0.0  ...  0.000000
# AG_AAACCCAAGACCACGA-45  0.000000  0.000000  0.000000     0.0  ...  0.693147
# AG_AAACCCAAGACCTCCG-24  0.000000  0.000000  0.000000     0.0  ...  0.000000
# AG_AAACCCAAGAGAGGTA-18  0.000000  0.000000  0.000000     0.0  ...  0.000000
# ...                          ...       ...       ...     ...  ...       ...
# TH_TTTGTTGTCGAACCAT-29  0.693147  0.000000  0.000000     0.0  ...  0.000000
# TH_TTTGTTGTCGAACCAT-32  1.386294  1.386294  0.000000     0.0  ...  0.693147
# TH_TTTGTTGTCGGAGTAG-32  0.693147  0.693147  0.000000     0.0  ...  0.000000
# TH_TTTGTTGTCTCGTTTA-9   0.693147  0.000000  0.000000     0.0  ...  0.000000
# TH_TTTGTTGTCTTGAACG-22  0.000000  0.000000  0.000000     0.0  ...  0.000000
#
#                         SPATC1L       LSS    MCM3AP      YBEY  C21orf58  \
# AG_AAACCCAAGAAATTCG-40      0.0  0.693147  1.386294  0.000000       0.0
# AG_AAACCCAAGACAACTA-20      0.0  0.693147  0.693147  0.000000       0.0
# AG_AAACCCAAGACCACGA-45      0.0  0.000000  0.000000  1.098612       0.0
# AG_AAACCCAAGACCTCCG-24      0.0  0.000000  0.000000  0.693147       0.0
# AG_AAACCCAAGAGAGGTA-18      0.0  0.000000  0.000000  0.000000       0.0
# ...                         ...       ...       ...       ...       ...
# TH_TTTGTTGTCGAACCAT-29      0.0  0.000000  0.000000  0.000000       0.0
# TH_TTTGTTGTCGAACCAT-32      0.0  2.772589  0.693147  0.000000       0.0
# TH_TTTGTTGTCGGAGTAG-32      0.0  1.098612  1.098612  0.000000       0.0
# TH_TTTGTTGTCTCGTTTA-9       0.0  1.098612  1.098612  0.000000       0.0
# TH_TTTGTTGTCTTGAACG-22      0.0  0.000000  0.000000  0.000000       0.0
#
#                             PCNT     DIP2A  S100B     PRMT2
# AG_AAACCCAAGAAATTCG-40  1.945910  0.000000    0.0  0.000000
# AG_AAACCCAAGACAACTA-20  1.098612  0.693147    0.0  0.000000
# AG_AAACCCAAGACCACGA-45  1.609438  1.098612    0.0  0.693147
# AG_AAACCCAAGACCTCCG-24  0.693147  0.000000    0.0  0.000000
# AG_AAACCCAAGAGAGGTA-18  0.000000  0.000000    0.0  0.000000
# ...                          ...       ...    ...       ...
# TH_TTTGTTGTCGAACCAT-29  0.000000  0.000000    0.0  0.000000
# TH_TTTGTTGTCGAACCAT-32  1.791759  1.945910    0.0  2.079442
# TH_TTTGTTGTCGGAGTAG-32  0.693147  1.609438    0.0  1.098612
# TH_TTTGTTGTCTCGTTTA-9   1.098612  0.000000    0.0  1.386294
# TH_TTTGTTGTCTTGAACG-22  0.000000  0.000000    0.0  0.000000
#
# [436014 rows x 17881 columns]

# %%
rd_trainer = rd.RegDiffusionTrainer(ex_matrix.to_numpy(), device="cpu")
rd_trainer.train()
# Out:
# Training loss: 0.278, Change on Adj: -0.000: 100%|██████████| 1000/1000 [1:35:58<00:00,  5.76s/it]

# %% [markdown]
# Extract edges from GRN

# %%
# Now we focus on edges with weight > 50 percentile. 
grn = rd_trainer.get_grn(ex_matrix.columns, top_gene_percentile = 50) # gene_names to recover non-expressed genes

# Here for each gene, we are going to extract all edges
adjacencies = grn.extract_edgelist(k = -1, workers = param_n_workers)
adjacencies.columns = ['TF', 'target', 'importance']

# check edgelist.  
adjacencies
# Out:
#                TF  target  importance
# 0           OR4F5  COL1A2    0.240479
# 1          SAMD11  COL1A2    0.085632
# 2          KLHL17  COL1A2    0.251465
# 3           PERM1  COL1A2    0.088379
# 4          RNF223  COL1A2    0.197632
# ...           ...     ...         ...
# 160098187  MCM3AP    YBEY    0.677246
# 160098188    PCNT    YBEY    0.821777
# 160098189   DIP2A    YBEY    0.627441
# 160098190   S100B    YBEY    0.457520
# 160098191   PRMT2    YBEY    1.488281
#
# [160098192 rows x 3 columns]

# %% [markdown]
# Read in the adjacencies matrix

# %%
adjacencies.to_csv(adj_matrix, index=False, sep=',')
#adjacencies = pd.read_csv(adj_matrix, sep=',', na_filter=False) # If na_filter=True, the nan gene is detected as NaN
adjacencies
# Out:
#                TF  target  importance
# 0           OR4F5  COL1A2    0.240479
# 1          SAMD11  COL1A2    0.085632
# 2          KLHL17  COL1A2    0.251465
# 3           PERM1  COL1A2    0.088379
# 4          RNF223  COL1A2    0.197632
# ...           ...     ...         ...
# 160098187  MCM3AP    YBEY    0.677246
# 160098188    PCNT    YBEY    0.821777
# 160098189   DIP2A    YBEY    0.627441
# 160098190   S100B    YBEY    0.457520
# 160098191   PRMT2    YBEY    1.488281
#
# [160098192 rows x 3 columns]

# %% [markdown]
# ## STEP 2-3: Regulon prediction aka cisTarget
#
# *Output:* List of adjacencies between a TF and its targets.
#
# ### 2.a. Running regulon prediction using cisTarget
#
# Here, we use the --mask_dropouts option, which affects how the correlation between TF and target genes is calculated during module creation. It is important to note that prior to pySCENIC v0.9.18, the default behavior was to mask dropouts, while in v0.9.18 and later, the correlation is performed using the entire set of cells (including those with zero expression). When using the modules_from_adjacencies function directly in python instead of via the command line, the rho_mask_dropouts option can be used to control this.

# %% [markdown]
# **Note:** I kept same parameters than when I ran pySCENIC on our own dataset. It produces 1618 regulons when using TF list from Aerts.

# %%
modules = list(modules_from_adjacencies(adjacencies, ex_matrix, rho_mask_dropouts=True, keep_only_activating=True)) # rho_mask_dropouts=True
# Out:
# 2025-05-12 08:47:51,070 - pyscenic.utils - INFO - Calculating Pearson correlations.
#
# 2025-05-12 08:48:11,790 - pyscenic.utils - WARNING - Note on correlation calculation: the default behaviour for calculating the correlations has changed after pySCENIC verion 0.9.16. Previously, the default was to calculate the correlation between a TF and target gene using only cells with non-zero expression values (mask_dropouts=True). The current default is now to use all cells to match the behavior of the R verision of SCENIC. The original settings can be retained by setting 'rho_mask_dropouts=True' in the modules_from_adjacencies function, or '--mask_dropouts' from the CLI.
# 	Dropout masking is currently set to [True].

# %%
modules_df = pd.DataFrame(index = range(0, len(modules)), columns = ("Regulon", "TF", "TFTargetGenesCorrelation", "NbMarkers", "Context", "NES", "Markers"))
for j in range(0, len(modules)):
    # Setting values
    context = list(modules[j].context)
    modules_df["Regulon"].iloc[j] = modules[j].name
    modules_df["TF"].iloc[j] = modules[j].transcription_factor
    modules_df["TFTargetGenesCorrelation"].iloc[j] = context[0]
    modules_df["NbMarkers"].iloc[j] = len(set(modules[j].gene2weight))
    modules_df["Context"].iloc[j] = context[1]
    modules_df["NES"].iloc[j] = modules[j].score
    modules_df["Markers"].iloc[j] = ','.join(list(modules[j].gene2weight))

modules_df = modules_df.sort_values(by='NbMarkers', ascending=False)
modules_df.to_csv(f_modules_path, index=False, sep = "\t")
modules_df

# %%
print(modules_df.TF.nunique(), "unique TF-modules were found ( out of",len(tf_names),"). Modules with less than 20 markers were filtered out.")

# %%
start = datetime.now(pytz.timezone('Europe/Paris'))
print("Start time:", start.strftime("%H:%M:%S"))

df = prune2df(dbs, modules, f_motif_path, num_workers=default_n_threads, weighted_recovery=False, rank_threshold = 1500, nes_threshold=3, motif_similarity_fdr=0.001, auc_threshold=0.05, filter_for_annotation=False)
    
end = datetime.now(pytz.timezone('Europe/Paris'))
print("End time:", end.strftime("%H:%M:%S"))
print("Running time:", (end - start))
# Note: 36mn27 with num_workers=12

df.to_csv(f_motifs_path,sep = "\t")
#df

# %%
print(len(set(df.index.get_level_values('TF').values)), "regulons were kept, after pruning")

# %%
# Look for main regulons
print("ATF4", "ATF4" in df.index.get_level_values('TF').values, sep="\t")

# %%
print("Size of Dataframe:", len(df))
drop_indexes = []
for j in range(0, len(df)):
    # Setting values
    if(len(df["Enrichment"]["TargetGenes"][j]) == 0): drop_indexes.append(df.index[j])
df_filtered = df["Enrichment"].drop(index=drop_indexes)
print("Size of Dataframe:", len(df_filtered))

# %% [markdown]
# These "modules" are then combined into regulons, by taking the top NES for each TF (for main Motif, and final score of regulon). All genes are bundled together.

# %%
# This dataframe can then be converted to regulons.
regulons = df2regulons(df_filtered)

# %%
regulon_df = pd.DataFrame(index = range(0, len(regulons)), columns = ("Regulon", "TF", "TFTargetGenesCorrelation", "NbMarkers", "Motif", "NES", "Markers"))
for j in range(0, len(regulons)):
    # Fixing order of set
    context = list(regulons[j].context)
    if(context[0].endswith(".png")):
        tmp = context[0]
        context[0] = context[1]
        context[1] = tmp
    # Setting values
    regulon_df["Regulon"].iloc[j] = regulons[j].name
    regulon_df["TF"].iloc[j] = regulons[j].transcription_factor
    regulon_df["TFTargetGenesCorrelation"].iloc[j] = context[0]
    regulon_df["NbMarkers"].iloc[j] = len(set(regulons[j].gene2weight))
    regulon_df["Motif"].iloc[j] = "https://resources.aertslab.org/cistarget/motif_collections/v10nr_clust_public/logos/" + context[1]
    regulon_df["NES"].iloc[j] = regulons[j].score
    regulon_df["Markers"].iloc[j] = ','.join(list(regulons[j].gene2weight))

regulon_df = regulon_df.sort_values(by='NbMarkers', ascending=False)
regulon_df.to_csv(f_regulons_path, index=False, sep = "\t")
regulon_df

# %%
# Look for main regulons
print("ATF4", "ATF4" in df.index.get_level_values('TF').values, sep="\t")

# %% [markdown]
# ## Phase III: Cellular regulon enrichment matrix (aka AUCell)
#
# Characterize the different cells in a single-cell transcriptomics experiment by the enrichment of the regulons. Enrichment of a regulon is measures as AUC of the recovery curve of the genes that define this regulon.

# %%
auc_mtx = aucell(ex_matrix, regulons, num_workers=default_n_threads)
auc_mtx.to_csv(f_regulons_aucell_path, sep = "\t")
auc_mtx

# %%
# Checkpoint to regenerate the object from the file
#auc_mtx = pd.read_csv(f_regulons_aucell_path, sep = "\t", index_col = "Cell")
#auc_mtx.columns.name = "Regulon"
#auc_mtx

# %%
start = datetime.now(pytz.timezone('Europe/Paris'))
print("Start time:", start.strftime("%H:%M:%S"))

auc_mtx_bin = binarize(auc_mtx, seed = 42, num_workers=default_n_threads)

end = datetime.now(pytz.timezone('Europe/Paris'))
print("End time:", end.strftime("%H:%M:%S"))
print("Running time:", (end - start))

# Note: 04h21mn56 with num_workers=12

# %%
binarization_thresholds = auc_mtx_bin[1]
binarization_thresholds.to_csv(f_regulons_binarization_thresholds_aucell_path, sep = "\t")
binarization_thresholds

# %%
auc_mtx_bin = auc_mtx_bin[0]
auc_mtx_bin.to_csv(f_regulons_binarized_aucell_path, sep = "\t")
auc_mtx_bin

# %%
sum(auc_mtx_bin["ATF4(+)"])

# %%
binarization_thresholds.loc['ATF4(+)']

# %%
sum(auc_mtx["ATF4(+)"] > binarization_thresholds.loc['ATF4(+)'])
