# %% [markdown]
# # Emma Pan Neuro (Control + ND75KD) - pySCENIC pipeline (CLI version)
#
# **Author:** Vincent Gardeux
#
# **Date Created:** 03/01/2024

# %% [markdown]
# # Libraries

# %%
# import dependencies
import os
import numpy as np
import pandas as pd
import scanpy as sc
import loompy as lp
from MulticoreTSNE import MulticoreTSNE as TSNE

# %% [markdown]
# # Parameters

# %%
# Parameters for scanpy
sc.settings.verbosity = 3 # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_versions()
sc.set_figure_params(dpi=150, fontsize=10, dpi_save=600)
sc.settings.njobs = 32 # Set maximum number of jobs for Scanpy (also used in GRNBoost2)

# [Input] Loom file to use
f_loom_path_scenic = "/home/gardeux/SVRAW1/gardeux/2023-04-19_Emma_snRNAseq/analysis/Pan_neuro_both_reannotated_GFP_curated_reintegrated.loom"

# [Input] Transcription factors list (SCENIC step 1: GRNBoost2)
f_tfs = "/data/genome/drosophila_melanogaster/cistopic_flybase_r6.02/allTFs_dmel.txt" # drosophila

# [Output] Adjacency matrix (SCENIC step 1: GRNBoost2)
adj_matrix = "/home/gardeux/SVRAW1/gardeux/2023-04-19_Emma_snRNAseq/analysis/Pan_neuro_both_reannotated_GFP_curated_reintegrated_adj.csv"

# [Input] Ranking databases (SCENIC step 2-3: cisTarget)
f_db_names = "/data/genome/drosophila_melanogaster/cistopic_flybase_r6.02/mc_v10_clust/dm6_v10_clust.genes_vs_motifs.rankings.feather"

# [Input] Motif databases (SCENIC step 2-3: cisTarget)
f_motif_path = "/data/genome/drosophila_melanogaster/cistopic_flybase_r6.02/mc_v10_clust/motifs-v10nr_clust-nr.flybase-m0.001-o0.0.tbl"

# [Output] Regulons (SCENIC step 2-3: cisTarget)
reg_matrix = "/home/gardeux/SVRAW1/gardeux/2023-04-19_Emma_snRNAseq/analysis/Pan_neuro_both_reannotated_GFP_curated_reintegrated_reg.csv"
# Out:
# -----
# anndata     0.10.3
# scanpy      1.9.3
# -----
# MulticoreTSNE       NA
# PIL                 8.2.0
# argcomplete         NA
# asttokens           NA
# astunparse          1.6.3
# awkward             2.3.1
# awkward_cpp         NA
# backcall            0.2.0
# cairo               1.21.0
# cffi                1.14.5
# cloudpickle         2.2.0
# colorama            0.4.6
# comm                0.1.3
# cycler              0.10.0
# cython_runtime      NA
# cytoolz             0.10.1
# dask                2021.06.0
# dateutil            2.8.2
# debugpy             1.6.7
# decorator           4.4.2
# dill                0.3.4
# entrypoints         0.3
# exceptiongroup      1.1.3
# executing           1.2.0
# fsspec              2023.4.0
# future_fstrings     NA
# google              NA
# h5py                3.7.0
# igraph              0.10.4
# ipykernel           6.25.0
# ipython_genutils    0.2.0
# ipywidgets          7.6.3
# isal                1.5.2
# jedi                0.18.0
# joblib              1.2.0
# kiwisolver          1.3.1
# leidenalg           0.9.1
# llvmlite            0.39.1
# loompy              3.0.7
# louvain             0.7.0
# lz4                 3.1.3
# matplotlib          3.5.1
# matplotlib_inline   NA
# mpl_toolkits        NA
# natsort             7.1.1
# numba               0.56.3
# numexpr             2.7.3
# numpy               1.23.5
# numpy_groupies      0.9.13
# opt_einsum          v3.3.0
# packaging           23.1
# pandas              1.5.3
# parso               0.8.2
# pexpect             4.8.0
# pickleshare         0.7.5
# pkg_resources       NA
# platformdirs        3.9.1
# plotly              5.13.1
# prompt_toolkit      3.0.39
# psutil              5.9.4
# ptyprocess          0.7.0
# pure_eval           0.2.2
# pyarrow             15.0.0
# pycparser           2.20
# pydev_ipython       NA
# pydevconsole        NA
# pydevd              2.9.5
# pydevd_file_utils   NA
# pydevd_plugins      NA
# pydevd_tracing      NA
# pyexpat             NA
# pygments            2.15.1
# pyparsing           2.4.7
# pytz                2021.1
# ruamel              NA
# scipy               1.11.1
# session_info        1.0.0
# setuptools_scm      NA
# six                 1.15.0
# sklearn             1.3.1
# sparse              0.14.0
# sphinxcontrib       NA
# stack_data          0.6.2
# tblib               1.7.0
# texttable           1.6.3
# threadpoolctl       2.1.0
# tlz                 0.10.1
# toolz               0.11.1
# torch               1.13.0+cu117
# tornado             6.3.1
# tqdm                4.65.0
# traitlets           5.9.0
# typing_extensions   NA
# wcwidth             0.2.5
# xxhash              2.0.2
# yaml                6.0.1
# zmq                 24.0.1
# zope                NA
# -----
# IPython             8.14.0
# jupyter_client      7.4.9
# jupyter_core        5.3.1
# notebook            6.5.5
# -----
# Python 3.9.5 (default, Jun 15 2022, 08:55:22) [GCC 8.5.0 20210514 (Red Hat 8.5.0-10)]
# Linux-4.18.0-477.15.1.el8_8.x86_64-x86_64-with-glibc2.28
# -----
# Session information updated at 2024-03-06 13:55

# %% [markdown]
# # SCENIC steps
#
# ## STEP 1: Gene regulatory network inference, and generation of co-expression modules
#
# ### 1.a. GRN inference using the GRNBoost2 algorithm
#
# For this step the CLI version of SCENIC is used. This step can be deployed on an High Performance Computing system. We use the counts matrix (without log transformation or further processing) from the loom file we wrote earlier.
#
# *Output:* List of adjacencies between a TF and its targets.

# %% [markdown]
# Run GRNBoost2 algorithm

# %%
# Here I run the CLI version from the Docker
# !docker run -it --rm --name pySCENIC \
    -v /data/genome/drosophila_melanogaster/cistopic_flybase_r6.02:/cistopic_flybase_r6.02 \
    -v /home/gardeux/SVRAW1/gardeux/2023-04-19_Emma_snRNAseq/analysis:/analysis \
    -w /analysis aertslab/pyscenic:0.12.1 \
    pyscenic grn \
    {f_loom_path_scenic.replace("/home/gardeux/SVRAW1/gardeux/2023-04-19_Emma_snRNAseq/", "/")} \
    {f_tfs.replace("/data/genome/drosophila_melanogaster/", "/")} \
    -o {adj_matrix.replace("/home/gardeux/SVRAW1/gardeux/2023-04-19_Emma_snRNAseq/", "/")} \
    --num_workers {sc.settings.njobs}

# Note: It takes ~2h to complete
# Out:
# 2024-03-06 11:00:06,775 - pyscenic.cli.pyscenic - INFO - Loading expression matrix.
#
# 2024-03-06 11:00:23,383 - pyscenic.cli.pyscenic - INFO - Inferring regulatory networks.
# preparing dask client
# parsing input
# creating dask graph
# 32 partitions
# computing dask graph
# not shutting down client, client was created externally
# finished
#
# 2024-03-06 12:44:45,916 - pyscenic.cli.pyscenic - INFO - Writing results to file.

# %% [markdown]
# Read in the adjacencies matrix

# %%
adjacencies = pd.read_csv(adj_matrix, sep=',')
#adjacencies.to_csv(adj_matrix.replace(".csv", ".tsv"), index=False, sep='\t')
adjacencies
# Out:
#               TF          target    importance
# 0             bi  lncRNA:CR32773  7.387206e+02
# 1         CG9650  lncRNA:CR44357  5.064458e+02
# 2            trv         CG34354  4.570765e+02
# 3        CG34354             trv  4.545700e+02
# 4             br           Mur2B  4.179730e+02
# ...          ...             ...           ...
# 4016712    Dgp-1             Hug  7.302217e-20
# 4016713     rump          CG8401  3.989110e-20
# 4016714     crol            Capa  3.451499e-20
# 4016715      pho            Ilp3  1.136389e-20
# 4016716      pho            Ilp2  3.013293e-21
#
# [4016717 rows x 3 columns]

# %% [markdown]
# ## STEP 2-3: Regulon prediction aka cisTarget from CLI
#
# For this step the CLI version of SCENIC is used. This step can be deployed on an High Performance Computing system.
#
# *Output:* List of adjacencies between a TF and its targets.
#
# ### 2.a. Running regulon prediction using cisTarget
#
# Here, we use the --mask_dropouts option, which affects how the correlation between TF and target genes is calculated during module creation. It is important to note that prior to pySCENIC v0.9.18, the default behavior was to mask dropouts, while in v0.9.18 and later, the correlation is performed using the entire set of cells (including those with zero expression). When using the modules_from_adjacencies function directly in python instead of via the command line, the rho_mask_dropouts option can be used to control this.

# %%
# Here I run the CLI version from the Docker
# !docker run -it --rm --name pySCENIC \
    -v /data/genome/drosophila_melanogaster/cistopic_flybase_r6.02:/cistopic_flybase_r6.02 \
    -v /home/gardeux/SVRAW1/gardeux/2023-04-19_Emma_snRNAseq/analysis:/analysis \
    -w /analysis aertslab/pyscenic:0.12.1 \
    pyscenic ctx \
    {adj_matrix.replace("/home/gardeux/SVRAW1/gardeux/2023-04-19_Emma_snRNAseq/", "/")} \
    {f_db_names.replace("/data/genome/drosophila_melanogaster/", "/")} \
    --annotations_fname {f_motif_path.replace("/data/genome/drosophila_melanogaster/", "/")} \
    --expression_mtx_fname {f_loom_path_scenic.replace("/home/gardeux/SVRAW1/gardeux/2023-04-19_Emma_snRNAseq/", "/")} \
    --output {reg_matrix.replace("/home/gardeux/SVRAW1/gardeux/2023-04-19_Emma_snRNAseq/", "/")} \
    #--mask_dropouts \
    --num_workers 12
            
# Note: It takes ~2mn to complete
# Out:
# 2024-03-06 19:00:57,846 - pyscenic.cli.pyscenic - INFO - Creating modules.
#
# 2024-03-06 19:00:59,393 - pyscenic.cli.pyscenic - INFO - Loading expression matrix.
#
# 2024-03-06 19:01:21,750 - pyscenic.utils - INFO - Calculating Pearson correlations.
#
# 2024-03-06 19:01:22,646 - pyscenic.utils - WARNING - Note on correlation calculation: the default behaviour for calculating the correlations has changed after pySCENIC verion 0.9.16. Previously, the default was to calculate the correlation between a TF and target gene using only cells with non-zero expression values (mask_dropouts=True). The current default is now to use all cells to match the behavior of the R verision of SCENIC. The original settings can be retained by setting 'rho_mask_dropouts=True' in the modules_from_adjacencies function, or '--mask_dropouts' from the CLI.
# 	Dropout masking is currently set to [False].
#
# 2024-03-06 19:03:25,003 - pyscenic.utils - INFO - Creating modules.
#
# 2024-03-06 19:06:17,636 - pyscenic.cli.pyscenic - INFO - Loading databases.
#
# 2024-03-06 19:06:17,724 - pyscenic.cli.pyscenic - INFO - Calculating regulons.
#
# 2024-03-06 19:06:17,725 - pyscenic.prune - INFO - Using 112 workers.
#
# 2024-03-06 19:06:17,725 - pyscenic.prune - INFO - Using 112 workers.
#
# 2024-03-06 19:06:18,584 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(1): database loaded in memory.
#
# 2024-03-06 19:06:18,584 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(1): database loaded in memory.
#
# 2024-03-06 19:06:18,746 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(2): database loaded in memory.
#
# 2024-03-06 19:06:18,746 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(2): database loaded in memory.
#
# 2024-03-06 19:06:18,795 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(3): database loaded in memory.
#
# 2024-03-06 19:06:18,795 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(3): database loaded in memory.
#
# 2024-03-06 19:06:18,817 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(4): database loaded in memory.
#
# 2024-03-06 19:06:18,817 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(4): database loaded in memory.
#
# 2024-03-06 19:06:18,981 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(5): database loaded in memory.
#
# 2024-03-06 19:06:18,981 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(5): database loaded in memory.
#
# 2024-03-06 19:06:19,005 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(6): database loaded in memory.
#
# 2024-03-06 19:06:19,005 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(6): database loaded in memory.
#
# 2024-03-06 19:06:19,029 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(7): database loaded in memory.
#
# 2024-03-06 19:06:19,029 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(7): database loaded in memory.
#
# 2024-03-06 19:06:19,085 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(8): database loaded in memory.
#
# 2024-03-06 19:06:19,085 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(8): database loaded in memory.
#
# 2024-03-06 19:06:19,163 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(10): database loaded in memory.
#
# 2024-03-06 19:06:19,163 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(10): database loaded in memory.
#
# 2024-03-06 19:06:19,181 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(9): database loaded in memory.
#
# 2024-03-06 19:06:19,181 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(9): database loaded in memory.
#
# 2024-03-06 19:06:19,335 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(11): database loaded in memory.
#
# 2024-03-06 19:06:19,335 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(11): database loaded in memory.
#
# 2024-03-06 19:06:19,343 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(12): database loaded in memory.
#
# 2024-03-06 19:06:19,343 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(12): database loaded in memory.
#
# 2024-03-06 19:06:19,423 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(13): database loaded in memory.
#
# 2024-03-06 19:06:19,423 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(13): database loaded in memory.
#
# 2024-03-06 19:06:19,443 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(1): motif annotations loaded in memory.
#
# 2024-03-06 19:06:19,443 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(1): motif annotations loaded in memory.
#
# 2024-03-06 19:06:19,479 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(14): database loaded in memory.
#
# 2024-03-06 19:06:19,479 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(14): database loaded in memory.
#
# 2024-03-06 19:06:19,650 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(15): database loaded in memory.
#
# 2024-03-06 19:06:19,650 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(15): database loaded in memory.
#
# 2024-03-06 19:06:19,698 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(16): database loaded in memory.
#
# 2024-03-06 19:06:19,698 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(16): database loaded in memory.
#
# 2024-03-06 19:06:19,707 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(2): motif annotations loaded in memory.
#
# 2024-03-06 19:06:19,707 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(2): motif annotations loaded in memory.
#
# 2024-03-06 19:06:19,713 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(3): motif annotations loaded in memory.
#
# 2024-03-06 19:06:19,713 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(3): motif annotations loaded in memory.
# terminate called after throwing an instance of 'std::system_error'
#   what():  Resource temporarily unavailable
# terminate called after throwing an instance of 'std::system_error'
#   what():  Resource temporarily unavailable
#
# 2024-03-06 19:06:19,729 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(4): motif annotations loaded in memory.
#
# 2024-03-06 19:06:19,729 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(4): motif annotations loaded in memory.
# terminate called after throwing an instance of 'std::system_error'
#   what():  Resource temporarily unavailable
# terminate called after throwing an instance of 'std::system_error'
#   what():  Resource temporarily unavailable
# Traceback (most recent call last):
#   File "/opt/venv/bin/pyscenic", line 33, in <module>
#     sys.exit(load_entry_point('pyscenic==0.12.1+0.gce41b61.dirty', 'console_scripts', 'pyscenic')())
#   File "/opt/venv/lib/python3.10/site-packages/pyscenic/cli/pyscenic.py", line 713, in main
#     args.func(args)
#   File "/opt/venv/lib/python3.10/site-packages/pyscenic/cli/pyscenic.py", line 236, in prune_targets_command
#     df_motifs = calc_func(
#   File "/opt/venv/lib/python3.10/site-packages/pyscenic/prune.py", line 424, in prune2df
#     return _distributed_calc(
#   File "/opt/venv/lib/python3.10/site-packages/pyscenic/prune.py", line 245, in _distributed_calc
#     ).start()
#   File "/opt/venv/lib/python3.10/site-packages/multiprocessing_on_dill/process.py", line 105, in start
#     self._popen = self._Popen(self)
#   File "/opt/venv/lib/python3.10/site-packages/multiprocessing_on_dill/context.py", line 212, in _Popen
#     return _default_context.get_context().Process._Popen(process_obj)
#   File "/opt/venv/lib/python3.10/site-packages/multiprocessing_on_dill/context.py", line 267, in _Popen
#     return Popen(process_obj)
#   File "/opt/venv/lib/python3.10/site-packages/multiprocessing_on_dill/popen_fork.py", line 20, in __init__
#     self._launch(process_obj)
#   File "/opt/venv/lib/python3.10/site-packages/multiprocessing_on_dill/popen_fork.py", line 67, in _launch
#     self.pid = os.fork()
# BlockingIOError: [Errno 11] Resource temporarily unavailable
# terminate called after throwing an instance of 'std::system_error'
#   what():  Resource temporarily unavailable
# 2024-03-06 19:06:19,914 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(7): motif annotations loaded in memory.
#
# 2024-03-06 19:06:19,914 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(7): motif annotations loaded in memory.
#
# 2024-03-06 19:06:19,926 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(6): motif annotations loaded in memory.
#
# 2024-03-06 19:06:19,926 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(6): motif annotations loaded in memory.
# terminate called after throwing an instance of 'std::system_error'
#   what():  Resource temporarily unavailable
# terminate called after throwing an instance of 'std::system_error'
#   what():  Resource temporarily unavailable
#
# 2024-03-06 19:06:19,984 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(10): motif annotations loaded in memory.
#
# 2024-03-06 19:06:19,984 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(10): motif annotations loaded in memory.
#
# 2024-03-06 19:06:19,995 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(5): motif annotations loaded in memory.
#
# 2024-03-06 19:06:19,995 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(5): motif annotations loaded in memory.
#
# 2024-03-06 19:06:20,026 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(8): motif annotations loaded in memory.
#
# 2024-03-06 19:06:20,026 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(8): motif annotations loaded in memory.
# terminate called after throwing an instance of 'std::system_error'
#   what():  Resource temporarily unavailable
#
# 2024-03-06 19:06:20,030 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(9): motif annotations loaded in memory.
#
# 2024-03-06 19:06:20,030 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(9): motif annotations loaded in memory.
#
# 2024-03-06 19:06:20,142 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(11): motif annotations loaded in memory.
#
# 2024-03-06 19:06:20,142 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(11): motif annotations loaded in memory.
#
# 2024-03-06 19:06:20,152 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(12): motif annotations loaded in memory.
#
# 2024-03-06 19:06:20,152 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(12): motif annotations loaded in memory.
#
# 2024-03-06 19:06:20,196 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(13): motif annotations loaded in memory.
#
# 2024-03-06 19:06:20,196 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(13): motif annotations loaded in memory.
#
# 2024-03-06 19:06:20,239 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(14): motif annotations loaded in memory.
#
# 2024-03-06 19:06:20,239 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(14): motif annotations loaded in memory.
#
# 2024-03-06 19:06:20,352 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(15): motif annotations loaded in memory.
#
# 2024-03-06 19:06:20,352 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(15): motif annotations loaded in memory.
#
# 2024-03-06 19:06:20,367 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(16): motif annotations loaded in memory.
#
# 2024-03-06 19:06:20,367 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(16): motif annotations loaded in memory.
#
# 2024-03-06 19:06:22,625 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Eip78C could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:22,872 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG2931 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:23,007 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG4546 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:23,134 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Hr4 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:23,171 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG11504 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:23,199 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG2964 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:23,437 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG4593 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:23,521 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for TfIIFalpha could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:23,528 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Prosalpha1 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:23,566 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG8319 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:23,585 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Psi could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:23,615 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Hr51 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:23,712 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ara could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:23,735 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for l(2)k10201 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:23,807 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Elba2 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:23,863 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Tfb4 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:23,919 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Ptip could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:23,932 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG8578 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:23,942 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for fru could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:23,949 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG11617 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:23,976 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG30178 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:23,992 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Abd-B could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:24,014 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Mondo could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:24,042 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for arg could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:24,078 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Cyt-c-d could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:24,084 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG4611 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
# 2024-03-06 19:06:24,233 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Hr83 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:24,234 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Ptx1 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:24,242 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ftz could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:24,252 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG9121 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:24,346 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Abl could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:24,398 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG4730 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:24,409 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for lab could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:24,501 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Ets21C could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:24,560 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Topors could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:24,570 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG9246 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:24,578 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG11839 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:24,730 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Myb could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:24,785 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ase could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:25,178 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG4854 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:25,278 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Sidpn could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:25,294 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Ets96B could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:25,364 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG9314 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:25,373 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG12071 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:25,406 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Hrb87F could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:25,431 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG31064 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:25,443 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for NC2alpha could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:25,488 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG4935 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:25,535 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for lbl could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:25,563 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ato could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:25,665 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Trax could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:25,692 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for gcm could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:25,793 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG5023 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:25,799 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for DNApol-iota could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:25,853 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Antp could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:25,925 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Sirt6 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:25,953 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Trf could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:25,973 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for gcm2 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:25,991 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG12129 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:26,046 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for NELF-B could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:26,048 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG31388 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:26,120 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Dab could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:26,195 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Fer1 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:26,219 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for bab1 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:26,242 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG9609 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:26,247 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Six4 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:26,283 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for gem could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:26,359 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG31612 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:26,406 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG5116 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:26,437 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Hsf could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
# 2024-03-06 19:06:26,473 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for NK7.1 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:26,490 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for lin-28 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:26,525 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for bap could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:26,540 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG9650 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:26,580 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Dad could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:26,604 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG12219 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:26,661 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG31624 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:26,703 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG5144 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:26,748 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for danr could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:26,773 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Fer3 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:26,789 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for lmd could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:26,821 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for bbx could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:26,865 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for glo could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:26,874 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Dbx could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:26,991 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Irbp18 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:26,998 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG5180 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:27,039 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for dar1 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:27,083 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for lms could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:27,103 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG9876 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:27,139 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for bi could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:27,142 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Asap could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:27,255 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG31674 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:27,296 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG5245 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:27,354 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for FoxK could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:27,444 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Asciz could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:27,559 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG31988 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:27,596 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG5285 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:27,644 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for FoxL1 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:27,751 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for dimm could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:27,817 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for bin could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:27,819 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for lov could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:27,829 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Dgp-1 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:27,862 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG32075 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:27,965 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for FoxP could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:27,972 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CR43670 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:27,972 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Nf-YA could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:28,030 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for UQCR-14L could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:28,039 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Atf-2 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:28,126 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for bnl could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:28,148 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for luna could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:28,149 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG12768 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:28,154 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG3251 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:28,179 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG5728 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:28,241 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for GATAd could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:28,241 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CR4575 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
# 2024-03-06 19:06:28,454 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG32532 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:28,615 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Ubx could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:28,730 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for mRpL1 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:28,741 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG3294 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:28,758 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG5890 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:28,786 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for bon could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:28,805 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Gem3 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:28,824 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Dlip3 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:28,886 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Nf1 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:29,058 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for dmrt11E could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:29,262 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for NfI could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:29,349 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for dmrt93B could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:29,452 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG3347 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:29,512 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for br could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:29,620 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for dmrt99B could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:29,705 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Doa could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:29,715 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG14641 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:29,742 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG33722 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:29,767 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG6083 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:29,789 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Gsc could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:29,878 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Nup107 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:30,043 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Usp39 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:30,044 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for dpn could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:30,137 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG14667 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:30,166 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG34031 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:30,209 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for H15 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:30,216 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Doc1 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:30,240 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Nup133 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:30,327 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for RIOK2 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:30,427 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG14718 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:30,450 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG3407 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:30,475 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG6388 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:30,575 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Doc2 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:30,589 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for dsf could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:30,621 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Vsx1 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:30,716 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG14860 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:30,758 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for HGTX could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:30,839 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for gsb could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:30,905 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for XRCC1 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:30,995 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Kah could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:31,010 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG15011 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:31,040 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for HHEX could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:31,051 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG6769 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:31,059 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG34354 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:31,079 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for mil could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
# 2024-03-06 19:06:31,140 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for OdsH could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:31,149 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for bsh could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:31,300 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG15601 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:31,321 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for HLH3B could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:31,336 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG7069 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:31,346 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG34367 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:31,404 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for gt could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:31,434 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for btd could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:31,456 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for dysf could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:31,511 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Xpac could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:31,556 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Kdm4A could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:31,590 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG15696 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:31,600 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for HLH4C could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:31,623 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Chrac-14 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:31,633 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG3708 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:31,666 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for mio could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:31,670 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Atf6 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:31,682 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for mirr could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:31,722 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for byn could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:31,739 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for e(y)1 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:31,840 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Kdm4B could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:31,923 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG3815 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:31,968 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Awh could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:32,015 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for cad could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:32,107 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Rb97D could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:32,129 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Kr could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:32,173 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG15812 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:32,195 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG7362 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:32,229 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CkIIalpha-i1 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:32,289 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for PICK1 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:32,309 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for caup could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# ...
#
# 2024-03-06 19:06:35,488 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG44422 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:35,512 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Rfx could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:35,556 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG8152 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:35,654 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(5): All regulons derived.
#
# 2024-03-06 19:06:35,654 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(5): All regulons derived.
#
# 2024-03-06 19:06:35,655 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(5): Done.
#
# 2024-03-06 19:06:35,655 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(5): Done.
#
# 2024-03-06 19:06:35,690 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG2608 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:35,784 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG4496 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:35,788 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(3): All regulons derived.
#
# 2024-03-06 19:06:35,788 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(3): All regulons derived.
#
# 2024-03-06 19:06:35,789 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(3): Done.
#
# 2024-03-06 19:06:35,789 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(3): Done.
#
# 2024-03-06 19:06:35,816 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Rox8 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:35,865 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for jing could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:35,999 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(2): All regulons derived.
#
# 2024-03-06 19:06:35,999 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(2): All regulons derived.
#
# 2024-03-06 19:06:36,000 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(2): Done.
#
# 2024-03-06 19:06:36,000 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(2): Done.
#
# 2024-03-06 19:06:36,022 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Poxn could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:36,027 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for exex could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:36,139 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for jumu could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:36,184 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(4): All regulons derived.
#
# 2024-03-06 19:06:36,184 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(4): All regulons derived.
#
# 2024-03-06 19:06:36,185 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(4): Done.
#
# 2024-03-06 19:06:36,185 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(4): Done.
#
# 2024-03-06 19:06:36,313 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for PpD3 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:36,316 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(9): All regulons derived.
#
# 2024-03-06 19:06:36,316 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(9): All regulons derived.
#
# 2024-03-06 19:06:36,318 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(9): Done.
#
# 2024-03-06 19:06:36,318 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(9): Done.
#
# 2024-03-06 19:06:36,319 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Hmx could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:36,610 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for fd102C could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:36,652 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG10431 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:36,870 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for fd19B could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:36,913 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG10463 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:36,916 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for nerfin-1 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
# 2024-03-06 19:06:37,091 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for RpS10a could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:37,257 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for fd59A could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:37,310 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Mettl14 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:37,317 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for nerfin-2 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:37,359 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for E(spl)mdelta-HLH could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:37,528 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for fd96Ca could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:37,575 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Mettl3 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:37,590 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for net could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:37,650 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for E(spl)mgamma-HLH could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:37,784 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for fd96Cb could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:38,045 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(14): All regulons derived.
#
# 2024-03-06 19:06:38,045 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(14): All regulons derived.
#
# 2024-03-06 19:06:38,047 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(14): Done.
#
# 2024-03-06 19:06:38,047 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(14): Done.
#
# 2024-03-06 19:06:38,136 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG11085 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:38,146 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for nom could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:38,583 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CG11360 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:38,834 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Rrp1 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:38,863 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(1): All regulons derived.
#
# 2024-03-06 19:06:38,863 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(1): All regulons derived.
#
# 2024-03-06 19:06:38,869 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(1): Done.
#
# 2024-03-06 19:06:38,869 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(1): Done.
#
# 2024-03-06 19:06:38,913 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ECSIT could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:39,035 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(13): All regulons derived.
#
# 2024-03-06 19:06:39,035 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(13): All regulons derived.
#
# 2024-03-06 19:06:39,037 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(13): Done.
#
# 2024-03-06 19:06:39,037 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(13): Done.
#
# 2024-03-06 19:06:39,119 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Rrp40 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:39,124 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for nos could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:39,398 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for nub could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:39,403 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for RunxA could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:39,427 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for TfAP-2 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:39,660 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for nvy could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:39,663 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for RunxB could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:39,936 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Rx could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:39,937 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(16): All regulons derived.
#
# 2024-03-06 19:06:39,937 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(16): All regulons derived.
#
# 2024-03-06 19:06:39,939 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(16): Done.
#
# 2024-03-06 19:06:39,939 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(16): Done.
#
# 2024-03-06 19:06:40,196 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for kn could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:40,229 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for TfIIA-S-2 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:40,241 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(8): All regulons derived.
#
# 2024-03-06 19:06:40,241 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(8): All regulons derived.
#
# 2024-03-06 19:06:40,245 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(8): Done.
#
# 2024-03-06 19:06:40,245 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(8): Done.
#
# 2024-03-06 19:06:40,460 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SF1 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:40,489 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(11): All regulons derived.
#
# 2024-03-06 19:06:40,489 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(11): All regulons derived.
#
# 2024-03-06 19:06:40,491 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(11): Done.
#
# 2024-03-06 19:06:40,491 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(11): Done.
#
# 2024-03-06 19:06:40,942 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Hr39 could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:40,946 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(7): All regulons derived.
#
# 2024-03-06 19:06:40,946 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(7): All regulons derived.
#
# 2024-03-06 19:06:40,949 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(7): Done.
#
# 2024-03-06 19:06:40,949 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(7): Done.
# 2024-03-06 19:06:41,203 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for l(1)sc could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:41,432 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for l(2)37Cd could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:41,830 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for l(2)dtl could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:41,833 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(15): All regulons derived.
#
# 2024-03-06 19:06:41,833 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(15): All regulons derived.
#
# 2024-03-06 19:06:41,838 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(15): Done.
#
# 2024-03-06 19:06:41,838 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(15): Done.
#
# 2024-03-06 19:06:42,070 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Eip74EF could be mapped to dm6_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2024-03-06 19:06:42,378 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(6): All regulons derived.
#
# 2024-03-06 19:06:42,378 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(6): All regulons derived.
#
# 2024-03-06 19:06:42,380 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(6): Done.
#
# 2024-03-06 19:06:42,380 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(6): Done.
#
# 2024-03-06 19:06:42,763 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(10): All regulons derived.
#
# 2024-03-06 19:06:42,763 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(10): All regulons derived.
#
# 2024-03-06 19:06:42,770 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(10): Done.
#
# 2024-03-06 19:06:42,770 - pyscenic.prune - INFO - Worker dm6_v10_clust.genes_vs_motifs.rankings(10): Done.

# %%
regulons = pd.read_csv(reg_matrix, sep=',')
regulons
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 regulons = pd.read_csv(reg_matrix, sep=',')
#       2 regulons
#
# File /usr/local/lib/python3.9/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File /usr/local/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /usr/local/lib/python3.9/site-packages/pandas/io/parsers/readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File /usr/local/lib/python3.9/site-packages/pandas/io/parsers/readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File /usr/local/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File /usr/local/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1753, in TextFileReader._make_engine(self, f, engine)
#    1750     raise ValueError(msg)
#    1752 try:
# -> 1753     return mapping[engine](f, **self.options)
#    1754 except Exception:
#    1755     if self.handles is not None:
#
# File /usr/local/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py:79, in CParserWrapper.__init__(self, src, **kwds)
#      76     kwds.pop(key, None)
#      78 kwds["dtype"] = ensure_dtype_objs(kwds.get("dtype", None))
# ---> 79 self._reader = parsers.TextReader(src, **kwds)
#      81 self.unnamed_cols = self._reader.unnamed_cols
#      83 # error: Cannot determine type of 'names'
#
# File /usr/local/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:554, in pandas._libs.parsers.TextReader.__cinit__()
#
# EmptyDataError: No columns to parse from file

# %%
regulons = pd.read_csv(reg_matrix, sep=',')
regulons
# Out:
#     Unnamed: 0         Unnamed: 1            Enrichment        Enrichment.1  \
# 0          NaN                NaN                   AUC                 NES
# 1           TF            MotifID                   NaN                 NaN
# 2         Atf3     stark__TGANTCA   0.05681504924880987   4.666138672306601
# 3         Atf3  metacluster_148.1  0.049568211457107415   3.173405446015911
# 4         Atf3  metacluster_157.2   0.05377344487208033   4.039616588484887
# ..         ...                ...                   ...                 ...
# 279        srp  metacluster_117.4   0.06427245428554983  5.9103326489220915
# 280        srp  metacluster_117.7   0.05220225646142333   3.774395080426182
# 281        srp  metacluster_169.2    0.0685249055010841    6.66284478184673
# 282         tj  tfdimers__MD00092   0.09257796501082441   3.113835207142027
# 283         tj  tfdimers__MD00028   0.09124685506991984  3.0104484824509816
#
#               Enrichment.2         Enrichment.3  \
# 0    MotifSimilarityQvalue  OrthologousIdentity
# 1                      NaN                  NaN
# 2              3.99369e-06             0.068314
# 3                      0.0             0.307087
# 4                      0.0                0.384
# ..                     ...                  ...
# 279                    0.0                  1.0
# 280                    0.0                  1.0
# 281                    0.0                  1.0
# 282            2.71523e-07             0.391026
# 283            5.04243e-11             0.212613
#
#                                           Enrichment.4  \
# 0                                           Annotation
# 1                                                  NaN
# 2    gene is orthologous to ENSG00000162772 in H. s...
# 3    motif is annotated for orthologous gene ENSG00...
# 4    motif is annotated for orthologous gene ENSG00...
# ..                                                 ...
# 279                         gene is directly annotated
# 280                         gene is directly annotated
# 281                         gene is directly annotated
# 282  motif similar to tfdimers__MD00162 ('M01721_fo...
# 283  gene is orthologous to ENSG00000182759 in H. s...
#
#                                           Enrichment.5  \
# 0                                              Context
# 1                                                  NaN
# 2    frozenset({'weight>75.0%', 'dm6_v10_clust.gene...
# 3    frozenset({'weight>75.0%', 'dm6_v10_clust.gene...
# 4    frozenset({'weight>75.0%', 'dm6_v10_clust.gene...
# ..                                                 ...
# 279  frozenset({'activating', 'dm6_v10_clust.genes_...
# 280  frozenset({'activating', 'dm6_v10_clust.genes_...
# 281  frozenset({'activating', 'dm6_v10_clust.genes_...
# 282  frozenset({'activating', 'dm6_v10_clust.genes_...
# 283  frozenset({'activating', 'dm6_v10_clust.genes_...
#
#                                           Enrichment.6 Enrichment.7
# 0                                          TargetGenes    RankAtMax
# 1                                                  NaN          NaN
# 2    [('CG42748', 1.12564711607615), ('Gclm', 1.078...          457
# 3    [('Ac13E', 0.7477660264325211), ('Dh31-R', 1.1...         4988
# 4    [('CG42784', 1.511065204057486), ('Fim', 3.418...          652
# ..                                                 ...          ...
# 279  [('Ac13E', 15.015438165840512), ('CG17646', 9....         4765
# 280  [('Idh', 9.23347691913659), ('mbc', 6.78963765...         4725
# 281  [('dpp', 2.5538793133476654), ('for', 24.07611...         4996
# 282  [('msi', 4.820953696086392), ('bru2', 4.166019...          635
# 283  [('shep', 1.754661006506003), ('para', 4.42259...          296
#
# [284 rows x 10 columns]
